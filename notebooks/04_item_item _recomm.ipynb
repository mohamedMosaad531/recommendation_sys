# %%
DATA_PATH=r'..\data\processed\new_data.pickle'
MLFLOW_TRACKING_URI = '../models/mlruns/'
MLFLOW_EXPERIMENT_NAME = "Amazon_products_recommendation_system"

LOG_PATH = "../models/temp/"
LOG_DATA_PKL    =  "data.pkl"
LOG_MODEL_PKL   =  "model.pkl"
LOG_METRICS_PKL =  "metrics.pkl"

# %%
import pickle
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn
import mlflow
from mlflow import MlflowClient
from pathlib import Path

import surprise
from surprise.dataset import Dataset,Reader
from surprise.model_selection import train_test_split,GridSearchCV
from surprise.prediction_algorithms.knns import KNNBasic
from surprise import accuracy as acc
import os

# %%
df=pd.read_pickle(DATA_PATH)
reader=Reader(rating_scale=(1,5))
data=Dataset.load_from_df(df[['User_ID','Product_ID','Ratings']],reader)
trainset,testset=train_test_split(data,test_size=.3, random_state=42,shuffle=True)

# %%
test_df=pd.DataFrame(testset,columns=['User_ID', 'Product_ID', 'Ratings'])
test_df
# Out:
#               User_ID  Product_ID  Ratings
# 0      A23R3EOZ837242  B00834SJSK      4.0
# 1      A1H98YV5K5BUX0  B001EQ4BVI      5.0
# 2      A36K2N527TXXJN  B000MX48VM      5.0
# 3      A1F1A0QQP2XVH5  B000R805L4      5.0
# 4       A2SPV96SGOEO2  B004J4VYEY      3.0
# ...               ...         ...      ...
# 18863   AIJQU979J6UFY  B00JP12170      4.0
# 18864   ATOKT8QYK967L  B005O7LJAE      2.0
# 18865   AK3GKIV8DEY8B  B000067O7T      3.0
# 18866   ARXU3FESTWMJJ  B001TH7GVE      5.0
# 18867   AO09RWV40IX78  B00DQZOD8Q      5.0
#
# [18868 rows x 3 columns]

# %% [markdown]
# baseline model for item-item similarity collaborative filtering

# %%
sim_options={'name':'cosine',
             'user_based':False}
base_model=KNNBasic(sim_options=sim_options)
base_model.fit(trainset)
predictions=base_model.test(testset)
accuracy=acc.rmse(predictions)
# Out:
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.0337

# %%
print(accuracy)
# Out:
# 1.0337281152632931

# %%
predictions
# Out:
# [Prediction(uid='A23R3EOZ837242', iid='B00834SJSK', r_ui=4.0, est=4.086802650736902, details={'actual_k': 22, 'was_impossible': False}),
#  Prediction(uid='A1H98YV5K5BUX0', iid='B001EQ4BVI', r_ui=5.0, est=5, details={'actual_k': 2, 'was_impossible': False}),
#  Prediction(uid='A36K2N527TXXJN', iid='B000MX48VM', r_ui=5.0, est=4.399978686111782, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='A1F1A0QQP2XVH5', iid='B000R805L4', r_ui=5.0, est=4.071022723463895, details={'actual_k': 14, 'was_impossible': False}),
#  Prediction(uid='A2SPV96SGOEO2', iid='B004J4VYEY', r_ui=3.0, est=4.117465519818745, details={'actual_k': 7, 'was_impossible': False}),
#  Prediction(uid='A4WEZJOIZIV4U', iid='B00EVVGAC6', r_ui=4.0, est=4.647933081524785, details={'actual_k': 17, 'was_impossible': False}),
#  Prediction(uid='A3D0UM4ZD2CMAW', iid='B004ZMG55I', r_ui=5.0, est=4.290062464508802, details={'was_impossible': True, 'reason': 'Not enough neighbors.'}),
#  Prediction(uid='A2LB4FLRZG6CUV', iid='B003XIJ3MW', r_ui=5.0, est=4.833333333333333, details={'actual_k': 6, 'was_impossible': False}),
#  Prediction(uid='A3UW23DBF2KHWC', iid='B00D6XW62I', r_ui=5.0, est=4.0, details={'actual_k': 1, 'was_impossible': False}),
#  Prediction(uid='A11YOTONCPRQ9S', iid='B0063705PE', r_ui=5.0, est=3.495870668333469, details={'actual_k': 8, 'was_impossible': False}),
#  Prediction(uid='A296QED1MV1V0J', iid='B00BOZ1Y46', r_ui=4.0, est=4.290062464508802, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A32T2H8150OJLU', iid='B009HPC21Y', r_ui=5.0, est=5, details={'actual_k': 3, 'was_impossible': False}),
#  Prediction(uid='A3TAS1AG6FMBQW', iid='B0002J2TLC', r_ui=5.0, est=5, details={'actual_k': 3, 'was_impossible': False}),
#  Prediction(uid='A3OXHLG6DIBRW8', iid='B00ATM1MHO', r_ui=5.0, est=4.546194128528708, details={'actual_k': 22, 'was_impossible': False}),
#  Prediction(uid='AL9WKVMRI6GFB', iid='B00AQRUW4Q', r_ui=4.0, est=4.100681056483815, details={'actual_k': 21, 'was_impossible': False}),
#  Prediction(uid='A3QDY9I0CNMD2W', iid='B000JLM50I', r_ui=5.0, est=4.290062464508802, details={'was_impossible': True, 'reason': 'Not enough neighbors.'}),
#  Prediction(uid='A3VI2VETB90ZG5', iid='B00GBATPFO', r_ui=5.0, est=4.533535709792031, details={'actual_k': 15, 'was_impossible': False}),
#  Prediction(uid='A38NHXL5257E3B', iid='B008KVUAGU', r_ui=4.0, est=5, details={'actual_k': 3, 'was_impossible': False}),
#  Prediction(uid='AGGAQLXPVGM5D', iid='B007XOQ3BQ', r_ui=4.0, est=5, details={'actual_k': 1, 'was_impossible': False}),
#  Prediction(uid='
details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='A21KNRUAA5RK5E', iid='B0001DBEM4', r_ui=5.0, est=4.166666666666667, details={'actual_k': 6, 'was_impossible': False}),
#  Prediction(uid='ATZJNEXX7LWD3', iid='B002V8C3W2', r_ui=4.0, est=3.5, details={'actual_k': 8, 'was_impossible': False}),
#  Prediction(uid='A1SDPA1J98UP4L', iid='B00139XOCI', r_ui=5.0, est=5, details={'actual_k': 1, 'was_impossible': False}),
#  Prediction(uid='A3DOPYDOS49I3T', iid='B00ARB5FLQ', r_ui=5.0, est=4.793550537658963, details={'actual_k': 34, 'was_impossible': False}),
#  Prediction(uid='A3DGJMO6VPG6FJ', iid='B003LYF5P2', r_ui=4.0, est=4.0, details={'actual_k': 1, 'was_impossible': False}),
#  Prediction(uid='A2QRXQPHDMFCQV', iid='B00AAHT8JC', r_ui=4.0, est=3.8148156263009136, details={'actual_k': 11, 'was_impossible': False}),
#  Prediction(uid='A3NXJDNTQK2YJL', iid='B00212NO6W', r_ui=5.0, est=4.833333333333333, details={'actual_k': 6, 'was_impossible': False}),
#  Prediction(uid='A3094EPI56GKZ6', iid='B008X9Z8NE', r_ui=5.0, est=4.877977496059849, details={'actual_k': 16, 'was_impossible': False}),
#  Prediction(uid='A3QNQQKJTL76H0', iid='B001TODUXA', r_ui=4.0, est=4.15382340380535, details={'actual_k': 13, 'was_impossible': False}),
#  Prediction(uid='A1W415JP5WEAJK', iid='B004YIZWYI', r_ui=5.0, est=4.0, details={'actual_k': 7, 'was_impossible': False}),
#  Prediction(uid='A34BZM6S9L7QI4', iid='B005DIQ2OC', r_ui=5.0, est=4.75, details={'actual_k': 12, 'was_impossible': False}),
#  Prediction(uid='A3OXHLG6DIBRW8', iid='B00HUDZ8MU', r_ui=5.0, est=4.532915917485663, details={'actual_k': 17, 'was_impossible': False}),
#  Prediction(uid='A36A1ZYZH8568P', iid='B002WE4HE2', r_ui=5.0, est=4.4337771390176, details={'actual_k': 23, 'was_impossible': False}),
#  Prediction(uid='A15QYHQH80W30L', iid='B00GTGETFG', r_ui=5.0, est=5, details={'actual_k': 2, 'was_impossible': False}),
#  Prediction(uid='A1RPTVW5VEOSI', iid='B004OBUFYW', r_ui=1.0, est=4.0, details={'actual_k': 1, 'was_impossible': False}),
#  Prediction(uid='ADPKRJ2BSFJ0I', iid='B006K551WQ', r_ui=5.0, est=4.290062464508802, details={'was_impossible': True, 'reason': 'Not enough neighbors.'}),
#  Prediction(uid='AGEWOMQ90BV8R', iid='B000N35A0Y', r_ui=5.0, est=4.290062464508802, details={'was_impossible': True, 'reason': 'Not enough neighbors.'}),
#  Prediction(uid='A34VRVI4CSI5RQ', iid='B004BLIQEG', r_ui=2.0, est=4.333333333333333, details={'actual_k': 3, 'was_impossible': False}),
#  Prediction(uid='A3OXHLG6DIBRW8', iid='B001C3V54O', r_ui=4.0, est=4.555555555555555, details={'actual_k': 9, 'was_impossible': False}),
#  Prediction(uid='A1ILWPH1GHUXE2', iid='B004431UBM', r_ui=3.0, est=2.3333333333333335, details={'actual_k': 3, 'was_impossible': False}),
#  Prediction(uid='A3M7BCQKSQAK4L', iid='B002A92OVM', r_ui=5.0, est=4.290062464508802, details={'was_impossible': True, 'reason': 'Not enough neighbors.'}),
#  Prediction(uid='A1URXSRV6WDHVY', iid='B004CLYEI2', r_ui=5.0, est=4.4, details={'actual_k': 5, 'was_impossible': False}),
#  Prediction(uid='A267FU71Z01CIH', iid='B005KG44V0', r_ui=5.0, est=4.175083317568801, details={'actual_k': 6, 'was_impossible': False}),
#  Prediction(uid='A2XXBZPQT5EXHV', iid='B004FA8NOQ', r_ui=5.0, est=5, details={'actual_k': 2, 'was_impossible': False}),
#  Prediction(uid='ARIDN94LOCQFD', iid='B0041Q38NU', r_ui=4.0, est=4.683097903773973, details={'actual_k': 19, 'was_impossible': False}),
#  Prediction(uid='A3V5F050GVZ56Q', iid='B005I7X3RC', r_ui=4.0, est=4.799327117223941, details={'actual_k': 30, 'was_impossible': False}),
#  Prediction(uid='ARXU3FESTWMJJ', iid='B003CYKYU2', r_ui=3.0, est=3.700371354372935, details={'actual_k': 13, 'was_impossible': False}),
#  Prediction(uid='A2PZXXPGLXXKZU', iid='B000B60H0G', r_ui=3.0, est=4.0, details={'actual_k': 1, 'was_impossible': False}),
#  Prediction(uid='A2ZR3YTMEEIIZ4', iid='B002OB4BK8', r_ui=5.0, est=4.290062464508802, details={'was_impossible': True, 'reason': 'Not enough neighbors.'}),
#  Prediction(uid='A11ED8O95W2103', iid='B001EQ4C8U', r_ui=5.0, est=4.290062464508802, details={'was_impossible': True, 'reason': 'Not enough neighbors.'}),
#  Prediction(uid='ANTN61S4L7WG9', iid='B0097CZHAU', r_ui=5.0, est=4.536492510879241, details={'actual_k': 22, 'was_impossible': False}),
#  Prediction(uid='AYGEKID3G7DPW', iid='B004DBD4TG', r_ui=3.0, est=4.290062464508802, details={'was_impossible': True, 'reason': 'Not enough neighbors.'}),
#  Prediction(uid='A32O98PFC3OP7K', iid='B003ES5ZUU', r_ui=5.0, est=4.074207795178938, details={'actual_k': 13, 'was_impossible': False}),
#  Prediction(uid='AXU3VKZE848IY', iid='B002V8C3W2', r_ui=5.0, est=3.4773415847542535, details={'actual_k': 8, 'was_impossible': False}),
#  Prediction(uid='A21I62TCDL4754', iid='B003BLQHN4', r_ui=5.0, est=4.333333333333333, details={'actual_k': 6, 'was_impossible': False}),
#  Prediction(uid='A3CJ7MHAS9IMAM', iid='B00109Y2DQ', r_ui=5.0, est=4.121895449150472, details={'actual_k': 7, 'was_impossible': False}),
#  Prediction(uid='A680RUE1FDO8B', iid='B00428N9OK', r_ui=4.0, est=4.331971386584913, details={'actual_k': 3, 'was_impossible': False}),
#  Prediction(uid='A1NAA1R38JSNHV', iid='B000TXEE14', r_ui=5.0, est=5, details={'actual_k': 2, 'was_impossible': False}),
#  Prediction(uid='A3LGT6UZL99IW1', iid='B002FB684E', r_ui=5.0, est=4.134371650660853, details={'actual_k': 14, 'was_impossible': False}),
#  Prediction(uid='A20951I210L0IB', iid='B00727FE5U', r_ui=3.0, est=1, details={'actual_k': 1, 'was_impossible': False}),
#  Prediction(uid='A54S9CIUV5VNB', iid='B002ZIMEMW', r_ui=4.0, est=4.557496981614596, details={'actual_k': 9, 'was_impossible': False}),
#  Prediction(uid='A3Q4TYJVAM4IRM', iid='B004F09CVO', r_ui=4.0, est=4.5, details={'actual_k': 4, 'was_impossible': False}),
#  Prediction(uid='A2SH6A32BE6NEV', iid='B0000VYJRY', r_ui=4.0, est=4.290062464508802, details={'was_impossible': True, 'reason': 'Not enough neighbors.'}),
#  Prediction(uid='A2L9OPJAAEK08Q', iid='B006LVZDSQ', r_ui=2.0, est=3.5, details={'actual_k': 2, 'was_impossible': False}),
#  Prediction(uid='A
r_ui=4.0, est=4.290062464508802, details={'was_impossible': True, 'reason': 'Not enough neighbors.'}),
#  Prediction(uid='A3QUDXLOJTKEP9', iid='B00JP12170', r_ui=5.0, est=4.90863570373688, details={'actual_k': 11, 'was_impossible': False}),
#  Prediction(uid='A1BXVZSQOJE6UE', iid='B00FSA8VQ2', r_ui=3.0, est=3.999000025946747, details={'actual_k': 6, 'was_impossible': False}),
#  Prediction(uid='A2S26YGSVXBCFL', iid='B00DBX371C', r_ui=5.0, est=4.203428866865267, details={'actual_k': 20, 'was_impossible': False}),
#  Prediction(uid='A2LCE1D0TW2XY0', iid='B002W2Y8PC', r_ui=5.0, est=4.0, details={'actual_k': 1, 'was_impossible': False}),
#  Prediction(uid='A1VQBEW0G4IH1J', iid='B005DEW4BQ', r_ui=3.0, est=4.25, details={'actual_k': 4, 'was_impossible': False}),
#  Prediction(uid='A23ZNGL704AW7O', iid='B00CZ6WAEQ', r_ui=5.0, est=4.004707776452061, details={'actual_k': 12, 'was_impossible': False}),
#  Prediction(uid='A1MRPX3RM48T2I', iid='B009NB8WR0', r_ui=4.0, est=4.25, details={'actual_k': 4, 'was_impossible': False}),
#  Prediction(uid='A18YMFFJW974QS', iid='B00AYQ433U', r_ui=5.0, est=4.888888888888889, details={'actual_k': 9, 'was_impossible': False}),
#  Prediction(uid='A23NSKTMSPPBTR', iid='B00562O8U0', r_ui=4.0, est=4.0, details={'actual_k': 2, 'was_impossible': False}),
#  Prediction(uid='A32NEDX6UVV8DE', iid='B005A0B7CA', r_ui=5.0, est=4.666666666666667, details={'actual_k': 3, 'was_impossible': False}),
#  Prediction(uid='A30J7WQV0ZNRXG', iid='B00COEBCXY', r_ui=5.0, est=3.5, details={'actual_k': 2, 'was_impossible': False}),
#  Prediction(uid='A3VI2VETB90ZG5', iid='B0079TOEQQ', r_ui=4.0, est=4.372368454818943, details={'actual_k': 24, 'was_impossible': False}),
#  Prediction(uid='A3TAS1AG6FMBQW', iid='B00C97AF16', r_ui=3.0, est=5, details={'actual_k': 6, 'was_impossible': False}),
#  Prediction(uid='A33HIV8RXRDM88', iid='B0043M668G', r_ui=5.0, est=3.8602550091614947, details={'actual_k': 14, 'was_impossible': False}),
#  Prediction(uid='A2J0IBS4PFRO2C', iid='B003CGMQ38', r_ui=1.0, est=4.0, details={'actual_k': 1, 'was_impossible': False}),
#  Prediction(uid='A26KXNN6H1IL0I', iid='B009OZUPUC', r_ui=5.0, est=4.28683258354163, details={'actual_k': 17, 'was_impossible': False}),
#  Prediction(uid='A1REY92IEZJUSX', iid='B000053HH5', r_ui=5.0, est=5, details={'actual_k': 1, 'was_impossible': False}),
#  Prediction(uid='A2ARDVMUGDFED6', iid='B0007U0GZM', r_ui=4.0, est=4.0, details={'actual_k': 4, 'was_impossible': False}),
#  Prediction(uid='A18FLOC8YQY0P8', iid='B0075SUK14', r_ui=5.0, est=5, details={'actual_k': 4, 'was_impossible': False}),
#  Prediction(uid='A3R19YKNL641X3', iid='B005INAU90', r_ui=3.0, est=4.0, details={'actual_k': 5, 'was_impossible': False}),
#  Prediction(uid='AGJRUK27RBVYS', iid='B005JZP3CQ', r_ui=5.0, est=3.8333333333333335, details={'actual_k': 6, 'was_impossible': False}),
#  Prediction(uid='A2TRXEZYU9GYY8', iid='B005CT56F8', r_ui=5.0, est=5, details={'actual_k': 9, 'was_impossible': False}),
#  Prediction(uid='A1P0JSFW184ZXJ', iid='B0035JD0DW', r_ui=4.0, est=4.71403585248571, details={'actual_k': 7, 'was_impossible': False}),
#  Prediction(uid='A6VXZ1EEPRTLV', iid='B001EYV9TM', r_ui=5.0, est=4.499830045991834, details={'actual_k': 18, 'was_impossible': False}),
#  Prediction(uid='A2RWHTNM5P3I8Y', iid='B00AYTW80M', r_ui=4.0, est=4.1, details={'actual_k': 10, 'was_impossible': False}),
#  Prediction(uid='A1ODOGXEYECQQ8', iid='B008AST7R6', r_ui=5.0, est=4.859467802415955, details={'actual_k': 7, 'was_impossible': False}),
#  Prediction(uid='A2BMZRO0H7TFCS', iid='B003VAM32E', r_ui=4.0, est=3.7511450381679388, details={'actual_k': 16, 'was_impossible': False}),
#  Prediction(uid='A28N2AWOVO2PB', iid='B005KFONIU', r_ui=5.0, est=4.108502877379258, details={'actual_k': 9, 'was_impossible': False}),
#  Prediction(uid='AVBLGXSWRN666', iid='B003ES547O', r_ui=3.0, est=4.0, details={'actual_k': 3, 'was_impossible': False}),
#  Prediction(uid='A2VAD79S4A06DD', iid='B003TM600U', r_ui=5.0, est=4.666666666666667, details={'actual_k': 3, 'was_impossible': False}),
#  Prediction(uid='A18U49406IPPIJ', iid='B00GJFGDUQ', r_ui=5.0, est=4.999999999999999, details={'actual_k': 7, 'was_impossible': False}),
#  Prediction(uid='A1ZM846Y7AUYD', iid='B002TOJXIA', r_ui=3.0, est=4.290062464508802, details={'was_impossible': True, 'reason': 'Not enough neighbors.'}),
#  Prediction(uid='ABQWMANK4AR63', iid='B002YU83YO', r_ui=5.0, est=4.1099534969987355, details={'actual_k': 18, 'was_impossible': False}),
#  Prediction(uid='AW6J9IILGOZY3', iid='B007W7PK04', r_ui=4.0, est=4.25034591687377, details={'actual_k': 13, 'was_impossible': False}),
#  Prediction(uid='A3Q1J68QY1MZQ9', iid='B00IZDLDCI', r_ui=2.0, est=4.0, details={'actual_k': 4, 'was_impossible': False}),
#  Prediction(uid='A5Q1FK0FWU7DH', iid='B00829TIEK', r_ui=1.0, est=4.114834031488554, details={'actual_k': 26, 'was_impossible': False}),
#  Prediction(uid='A38C12950IM24P', iid='B00DQZQPNM', r_ui=5.0, est=5, details={'actual_k': 6, 'was_impossible': False}),
#  Prediction(uid='A2X3L31KCXBHCL', iid='B0033A7K7A', r_ui=2.0, est=4.666775111840536, details={'actual_k': 3, 'was_impossible': False}),
#  Prediction(uid='A1WF4QNIE2Z3I7', iid='B000QUUFRW', r_ui=5.0, est=4.593938964290195, details={'actual_k': 12, 'was_impossible': False}),
#  Prediction(uid='A1LAGS8H4A2DR7', iid='B0074BW614', r_ui=3.0, est=3.822526078918236, details={'actual_k': 11, 'was_impossible': False}),
#  Prediction(uid='A15QYHQH80W30L', iid='B0008D76L0', r_ui=5.0, est=3.6666666666666665, details={'actual_k': 3, 'was_impossible': False}),
#  Prediction(uid='AM9APPMIE1BHZ', iid='B00884WH74', r_ui=5.0, est=4.234771000544153, details={'actual_k': 26, 'was_impossible': False}),
#  Prediction(uid
details={'actual_k': 2, 'was_impossible': False}),
#  Prediction(uid='AEL6CQNQXONBX', iid='B008H9BXMK', r_ui=5.0, est=4.439019087250441, details={'actual_k': 16, 'was_impossible': False}),
#  Prediction(uid='A2CIQEY05SPHTZ', iid='B001CHHVCU', r_ui=3.0, est=4.108505051719082, details={'actual_k': 19, 'was_impossible': False}),
#  Prediction(uid='A3QAO3QBCQF89T', iid='B0081FLFQE', r_ui=3.0, est=3.9984722377992776, details={'actual_k': 8, 'was_impossible': False}),
#  Prediction(uid='A14NA0W8ESGDSI', iid='B0088CJT4U', r_ui=5.0, est=4.228385253662797, details={'actual_k': 26, 'was_impossible': False}),
#  Prediction(uid='A2BMZRO0H7TFCS', iid='B003ZUXHV6', r_ui=4.0, est=3.5979420195295004, details={'actual_k': 10, 'was_impossible': False}),
#  Prediction(uid='A2VAD79S4A06DD', iid='B00077AA5Q', r_ui=5.0, est=4.873872406626232, details={'actual_k': 8, 'was_impossible': False}),
#  Prediction(uid='A2NYK9KWFMJV4Y', iid='B00HQCIDGI', r_ui=5.0, est=4.913043478260869, details={'actual_k': 23, 'was_impossible': False}),
#  Prediction(uid='A1PI8VBCXXSGC7', iid='B0088CJT4U', r_ui=3.0, est=4.127182185198137, details={'actual_k': 32, 'was_impossible': False}),
#  Prediction(uid='A1YEPFLLH42OU1', iid='B004SNCZ3K', r_ui=4.0, est=4.832499810519487, details={'actual_k': 6, 'was_impossible': False}),
#  Prediction(uid='A2WC9NFLG57W4H', iid='B00CKAOJA0', r_ui=5.0, est=3.8744154194646567, details={'actual_k': 16, 'was_impossible': False}),
#  Prediction(uid='A1T1YSCDW0PD25', iid='B0054QNL38', r_ui=4.0, est=4.75, details={'actual_k': 4, 'was_impossible': False}),
#  Prediction(uid='A9Y5O2R4D6EH5', iid='B005IA843W', r_ui=5.0, est=3.5658805383867187, details={'actual_k': 7, 'was_impossible': False}),
#  Prediction(uid='AGOH8N902URMW', iid='B00889ST2G', r_ui=5.0, est=5, details={'actual_k': 3, 'was_impossible': False}),
#  Prediction(uid='A2JMJVNTBL7K7E', iid='B002DWQU48', r_ui=2.0, est=3.0, details={'actual_k': 1, 'was_impossible': False}),
#  Prediction(uid='A1L64KDYO5BOJA', iid='B0002Y5WZM', r_ui=5.0, est=4.290062464508802, details={'was_impossible': True, 'reason': 'Not enough neighbors.'}),
#  Prediction(uid='AG2YXYIQ8TLTA', iid='B003X26LYG', r_ui=3.0, est=4.666666666666667, details={'actual_k': 3, 'was_impossible': False}),
#  Prediction(uid='A3A15L96IYUO6V', iid='B000N99BBC', r_ui=5.0, est=3.814377465883623, details={'actual_k': 21, 'was_impossible': False}),
#  Prediction(uid='A13BX9O5UDBILC', iid='B004E10KFG', r_ui=4.0, est=3.8390451275984776, details={'actual_k': 6, 'was_impossible': False}),
#  Prediction(uid='A2NVQZ4Y7Y0J1R', iid='B00ETBHOIM', r_ui=4.0, est=4.0, details={'actual_k': 1, 'was_impossible': False}),
#  Prediction(uid='A357B3PUHSVQA', iid='B005QCDY50', r_ui=3.0, est=4.2564520444556075, details={'actual_k': 24, 'was_impossible': False}),
#  Prediction(uid='A3DGJMO6VPG6FJ', iid='B00HPMCO4Q', r_ui=4.0, est=4.290062464508802, details={'was_impossible': True, 'reason': 'Not enough neighbors.'}),
#  Prediction(uid='A3PJJTAKISAFI9', iid='B005HMO6A6', r_ui=1.0, est=4.290062464508802, details={'was_impossible': True, 'reason': 'Not enough neighbors.'}),
#  Prediction(uid='AP53MVRC8ZEW2', iid='B007V5A1BK', r_ui=4.0, est=5, details={'actual_k': 1, 'was_impossible': False}),
#  Prediction(uid='A2KHG3JOFXQ4CE', iid='B002SQK2F2', r_ui=2.0, est=3.8135154085403986, details={'actual_k': 28, 'was_impossible': False}),
#  Prediction(uid='A3OXHLG6DIBRW8', iid='B00HMREOLK', r_ui=5.0, est=4.475428435844615, details={'actual_k': 21, 'was_impossible': False}),
#  Prediction(uid='A3EZEP0FX5BC1P', iid='B001DTCPBO', r_ui=4.0, est=4.0, details={'actual_k': 3, 'was_impossible': False}),
#  Prediction(uid='ABDR6IJ93HFIO', iid='B00011KM38', r_ui=5.0, est=4.888888888888889, details={'actual_k': 9, 'was_impossible': False}),
#  Prediction(uid='AC1YLEFC9AN5X', iid='B00DQZT0AC', r_ui=3.0, est=4.666666666666667, details={'actual_k': 3, 'was_impossible': False}),
#  Prediction(uid='A25C2M3QF9G7OQ', iid='B00HBYKVA2', r_ui=5.0, est=4.470733440734345, details={'actual_k': 34, 'was_impossible': False}),
#  Prediction(uid='A12EVK82QUTSA6', iid='B002K9IHGI', r_ui=5.0, est=4.2003433414243565, details={'actual_k': 10, 'was_impossible': False}),
#  Prediction(uid='A5GPH59NDWJRB', iid='B005DOUJL8', r_ui=4.0, est=3.663528523870508, details={'actual_k': 9, 'was_impossible': False}),
#  Prediction(uid='A3QQGPI3CTV9SX', iid='B000H6AY6M', r_ui=5.0, est=4.0, details={'actual_k': 1, 'was_impossible': False}),
#  Prediction(uid='A34DQINHT6NYJU', iid='B005QCDY50', r_ui=3.0, est=3.9567259551579057, details={'actual_k': 22, 'was_impossible': False}),
#  Prediction(uid='A5GPH59NDWJRB', iid='B003Y74AXO', r_ui=3.0, est=3.8536279498946167, details={'actual_k': 14, 'was_impossible': False}),
#  Prediction(uid='A3MFORLOKIOEQY', iid='B0033A7JG2', r_ui=5.0, est=4.8, details={'actual_k': 5, 'was_impossible': False}),
#  Prediction(uid='A12DQZKRKTNF5E', iid='B0060GEZ0E', r_ui=4.0, est=4.8, details={'actual_k': 5, 'was_impossible': False}),
#  Prediction(uid='AO09RWV40IX78', iid='B00DQZQCUI', r_ui=5.0, est=4.622207053855193, details={'actual_k': 8, 'was_impossible': False}),
#  ...]

# %%
# k=10
# threshold=3.5
from collections import defaultdict
def allmetrices(mdel,k=10,threshold=3.5):
    user_est_true=defaultdict(list)

    for uid,_,r_ui,est,_ in predictions:
        user_est_true[uid].append((r_ui,est))
    user_est_true 
    precisions=dict()
    recalls=dict()
    for uid,userrating in user_est_true.items():
        userrating.sort(key=lambda x:x[0],reverse=True)
        num_of_relevant=sum((r_ui>threshold) for (r_ui,_) in userrating )
        num_of_recommended=sum((est>threshold) for (_,est) in userrating[:k] )
        num_of_both=sum ((r_ui>=threshold) and (est>=threshold) for (r_ui,est) in userrating[:k]  ) 
        
        num_of_both=(sum(  (r_ui>=threshold) and (est>=threshold) for (r_ui,est) in userrating[:k]   ))

        precisions[uid]=num_of_both/num_of_recommended if num_of_recommended!=0 else 0

        recalls[uid]=num_of_both/num_of_relevant if num_of_relevant!=0 else 0

    precision=round((sum(prec for prec in precisions.values()) / len(precisions)), 3)
    recall = round((sum(rec for rec in recalls.values()) / len(recalls)), 3)
    f1_score=round(2*precision*recall/(precision+recall),3)
    accuracy=acc.rmse(predictions)
    return accuracy,precision,recall,f1_score

# %%
accuracy,precision,recall,f1=allmetrices(base_model)
print(accuracy,precision,recall,f1)
# Out:
# RMSE: 1.0337
# 1.0337281152632931 0.916 0.788 0.847

# %%
base_model.predict('A3LDPF5FMB782Z', '1400501466', r_ui=5, verbose=True)
# Out:
# user: A3LDPF5FMB782Z item: 1400501466 r_ui = 5.00   est = 4.18   {'actual_k': 22, 'was_impossible': False}
# Prediction(uid='A3LDPF5FMB782Z', iid='1400501466', r_ui=5, est=4.181818181818182, details={'actual_k': 22, 'was_impossible': False})

# %%
base_model.predict('A34BZM6S9L7QI4', '1400501466', verbose=True)
# Out:
# user: A34BZM6S9L7QI4 item: 1400501466 r_ui = None   est = 4.29   {'was_impossible': True, 'reason': 'Not enough neighbors.'}
# Prediction(uid='A34BZM6S9L7QI4', iid='1400501466', r_ui=None, est=4.290062464508802, details={'was_impossible': True, 'reason': 'Not enough neighbors.'})

# %%
base_model.get_neighbors(0, k=5)
# Out:
# [11, 23, 35, 60, 98]

# %%
def get_recommendations(data,user_id,top_n,model):
    user_item_interactions_matrix=df.pivot(index='User_ID',columns='Product_ID',values='Ratings')

    non_interacted_products=user_item_interactions_matrix.loc[user_id][user_item_interactions_matrix.loc[user_id].isnull()].index.tolist()
    recommendations=[]
    for i in non_interacted_products:
        est=model.predict('user_id',i).est
        recommendations.append((i,est))
    recommendations.sort(key=lambda x:x[1],reverse=True)    
    return recommendations[:top_n+1]

# %%
recommendations = get_recommendations(df, 'A1A5KUIIIHFF4U', 5, base_model)
recommendations
# Out:
# [('1400532655', 4.290062464508802),
#  ('9983891212', 4.290062464508802),
#  ('B00000DM9W', 4.290062464508802),
#  ('B00000J1V5', 4.290062464508802),
#  ('B00000JDF5', 4.290062464508802),
#  ('B00000JDF6', 4.290062464508802)]

# %%
mlflow.set_tracking_uri(MLFLOW_TRACKING_URI)
client=MlflowClient()
mlflow.get_experiment_by_name(MLFLOW_EXPERIMENT_NAME)
exp=client.get_experiment_by_name(MLFLOW_EXPERIMENT_NAME)
if exp is None:
    print("Experiment not found ,creating new experiment")
    experiment_id=mlflow.create_experiment(MLFLOW_EXPERIMENT_NAME)
else:
    experiment_id=exp.experiment_id

# %%
model = {"model_description": "KNNBZsiv=c: cosine similarity ----item-item based",
         "model_details": str(base_model),
         "model_object": base_model}

with open(os.path.join(LOG_PATH, LOG_MODEL_PKL), "wb") as output_file:
    pickle.dump(model, output_file)

# %%
metrices1={'accuracy: ':accuracy,
    'precision: ':precision,
    'recall: ' :recall,
    'f1_score: ':f1
          }
with open (os.path.join(LOG_PATH,LOG_METRICS_PKL),'wb') as output_file:
    pickle.dump(metrices1,output_file)

# %%
data1={'train_data : ':trainset,
      'test_data : ':testset  }
with open (os.path.join(LOG_PATH,LOG_DATA_PKL),'wb') as file:
    pickle.dump(data1,file)

# %%
with mlflow.start_run(experiment_id=exp.experiment_id,
                      run_name=model["model_description"]):
    # Log pickles
    mlflow.log_artifacts(LOG_PATH)

    # Track metrics
    mlflow.log_metric('precision', precision)
    mlflow.log_metric("recall", recall)
    mlflow.log_metric("f1_score", f1)
    mlflow.log_metric("accuracy", accuracy)

# %% [markdown]
# GridSearch for this collaborative filtering

# %%
param_grid={'k':[20,30,40,50],
            'min_k':[3,6,9],
            'sim_options':{'name':['cosine','msd','pearson'],
             'user_based':[False]}
             }
grid=GridSearchCV(KNNBasic,param_grid=param_grid,measures=['rmse'],cv=5)
grid.fit(data)
print(grid.best_score)
print(grid.best_params)
# Out:
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# {'rmse': 0.9664526073382156}
# {'rmse': {'k': 20, 'min_k': 6, 'sim_options': {'name': 'msd', 'user_based': False}}}

# %% [markdown]
# Building model with best hyberparameters

# %%
sim_options= {'name': 'msd', 'user_based': False}
knnbasic=KNNBasic(k=20,min_k=6,sim_options=sim_options)
knnbasic.fit(trainset)
# Out:
# Computing the msd similarity matrix...
# Done computing similarity matrix.

# %%
accuracy,precision,recall,f1=allmetrices(knnbasic)
print(accuracy,precision,recall,f1)
# Out:
# RMSE: 1.0337
# 1.0337281152632931 0.916 0.788 0.847

# %%
knnbasic.predict('A3LDPF5FMB782Z', '1400501466',r_ui=5, verbose=True)
# Out:
# user: A3LDPF5FMB782Z item: 1400501466 r_ui = 5.00   est = 4.62   {'actual_k': 20, 'was_impossible': False}
# Prediction(uid='A3LDPF5FMB782Z', iid='1400501466', r_ui=5, est=4.619718309859155, details={'actual_k': 20, 'was_impossible': False})

# %%
knnbasic.predict('A34BZM6S9L7QI4', '1400501466', verbose=True)
# Out:
# user: A34BZM6S9L7QI4 item: 1400501466 r_ui = None   est = 4.29   {'was_impossible': True, 'reason': 'Not enough neighbors.'}
# Prediction(uid='A34BZM6S9L7QI4', iid='1400501466', r_ui=None, est=4.290062464508802, details={'was_impossible': True, 'reason': 'Not enough neighbors.'})

# %%
recommendations = get_recommendations(data, 'A1A5KUIIIHFF4U', 5, knnbasic)
recommendations
# Out:
# [('1400532655', 4.290062464508802),
#  ('9983891212', 4.290062464508802),
#  ('B00000DM9W', 4.290062464508802),
#  ('B00000J1V5', 4.290062464508802),
#  ('B00000JDF5', 4.290062464508802),
#  ('B00000JDF6', 4.290062464508802)]

# %%
model = {"model_description": "KNNBasic:with gridsearch ----item-item based",
         "model_details": str(knnbasic),
         "model_object": knnbasic}

with open(os.path.join(LOG_PATH, LOG_MODEL_PKL), "wb") as output_file:
    pickle.dump(model, output_file)

# %%
metrices1={'accuracy: ':accuracy,
    'precision: ':precision,
    'recall: ' :recall,
    'f1_score: ':f1
          }
with open (os.path.join(LOG_PATH,LOG_METRICS_PKL),'wb') as output_file:
    pickle.dump(metrices1,output_file)

# %%
data1={'train_data : ':trainset,
      'test_data : ':testset  }
with open (os.path.join(LOG_PATH,LOG_DATA_PKL),'wb') as file:
    pickle.dump(data1,file)

# %%
with mlflow.start_run(experiment_id=exp.experiment_id,
                      run_name=model["model_description"]):
    # Log pickles
    mlflow.log_artifacts(LOG_PATH)

    # Track metrics
    mlflow.log_metric('precision', precision)
    mlflow.log_metric("recall", recall)
    mlflow.log_metric("f1_score", f1)
    mlflow.log_metric("accuracy", accuracy)
    mlflow.log_params({'k': 20, 
                       'min_k': 6,
                         'sim_options': {'name': 'msd', 'user_based': False}})
