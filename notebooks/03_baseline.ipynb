# %%
DATA_PATH=r'..\data\processed\new_data.pickle'
MLFLOW_TRACKING_URI = '../models/mlruns/'
MLFLOW_EXPERIMENT_NAME = "Amazon_products_recommendation_system"

LOG_PATH = "../models/temp/"
LOG_DATA_PKL    =  "data.pkl"
LOG_MODEL_PKL   =  "model.pkl"
LOG_METRICS_PKL =  "metrics.pkl"

# %%
import pickle
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn
import mlflow
from mlflow import MlflowClient
from pathlib import Path

# %%
df=pd.read_pickle(DATA_PATH)
df.head()
# Out:
#              User_ID  Product_ID  Ratings  year  month
# 1309  A3LDPF5FMB782Z  1400501466      5.0  2012      5
# 1321  A1A5KUIIIHFF4U  1400501466      1.0  2012      3
# 1334  A2XIOXRRYX0KZY  1400501466      3.0  2013      6
# 1450   AW3LX47IHPFRL  1400501466      5.0  2012      6
# 1455  A1E3OB6QMBKRYZ  1400501466      1.0  2012     10

# %%
mlflow.set_tracking_uri(MLFLOW_TRACKING_URI)
client=MlflowClient()
mlflow.get_experiment_by_name(MLFLOW_EXPERIMENT_NAME)
exp=client.get_experiment_by_name(MLFLOW_EXPERIMENT_NAME)
if exp is None:
    print("Experiment not found ,creating new experiment")
    experiment_id=mlflow.create_experiment(MLFLOW_EXPERIMENT_NAME)
else:
    experiment_id=exp.experiment_id

# %% [markdown]
# Rank-based recommendation sysetm

# %%
average_rating = df.groupby('Product_ID')['Ratings'].mean()

# Calculate the count of ratings for each product
count_rating = df.groupby('Product_ID')['Ratings'].count()

# Create a dataframe with calculated average and count of ratings
final_rating = pd.DataFrame({'avg_rating':average_rating, 'rating_count':count_rating})

# Sort the dataframe by average of ratings in the descending order
final_rating = final_rating.sort_values(by='avg_rating', ascending=False)

# See the first five records of the "final_rating" dataset
final_rating.head(5)
# Out:
#             avg_rating  rating_count
# Product_ID
# B00LGQ6HL8         5.0             5
# B004Y1AYAC         5.0            10
# B004Z0S6RU         5.0             8
# B000BOLHH0         5.0             5
# B0051QZEHC         5.0             5

# %%
Path(MLFLOW_TRACKING_URI).mkdir(parents=True, exist_ok=True)
Path(LOG_PATH).mkdir(parents=True, exist_ok=True)

# %%
final_rating.shape
# Out:
# (5523, 2)

# %%
# Defining a function to get the top n products based on the highest average rating and minimum interactions
def top_n_products(data, n, min_interaction=100):

    # Finding products with minimum number of interactions
    recommendations = data[data['rating_count'] > min_interaction]

    return recommendations.index[:n]
print(list(top_n_products(final_rating,5)))
# Out:
# ['B003ES5ZUU', 'B000N99BBC', 'B002V88HFE', 'B007WTAJTO', 'B004CLYEDC']

# %%
top_products=list(top_n_products(final_rating,5))
for i in top_products:
    print(final_rating.loc[i])
# Out:
# avg_rating        4.858757
# rating_count    177.000000
# Name: B003ES5ZUU, dtype: float64
# avg_rating        4.773006
# rating_count    163.000000
# Name: B000N99BBC, dtype: float64
# avg_rating        4.70297
# rating_count    101.00000
# Name: B002V88HFE, dtype: float64
# avg_rating        4.692308
# rating_count    156.000000
# Name: B007WTAJTO, dtype: float64
# avg_rating        4.666667
# rating_count    117.000000
# Name: B004CLYEDC, dtype: float64

# %% [markdown]
# Collaporative Filtiring Recommendation System

# %% [markdown]
# Building a baseline user-user similarity based recommendation system¶

# %%
from surprise import Dataset,Reader
from surprise.model_selection import train_test_split
from surprise.prediction_algorithms.knns import KNNBaseline
from surprise import accuracy as acc
from surprise.model_selection import GridSearchCV
import os

# %%
reader=Reader(rating_scale=(1,5))
data=Dataset.load_from_df(df[['User_ID','Product_ID','Ratings']], reader)
trainset,testset=train_test_split(data,test_size=.2, random_state=42)

# %%
data

# %% [markdown]
# Building the user-user Similarity-based Recommendation System

# %%
sim_options={'name':'cosine',
             'user_based':True}
base_model=KNNBaseline(sim_options=sim_options)
base_model.fit(trainset=trainset)
predictions=base_model.test(testset=testset)
accuracy=acc.rmse(predictions)
print(accuracy)
# Out:
# Estimating biases using als...
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# RMSE: 0.9415
# 0.9415216295051958

# %%
predictions
# Out:
# [Prediction(uid='AKBVYIIHWI04B', iid='B009SYZ8OC', r_ui=5.0, est=4.761802398863393, details={'actual_k': 20, 'was_impossible': False}),
#  Prediction(uid='A2MCRCK1V61FWQ', iid='B0009ZBRS0', r_ui=5.0, est=2.2897962321539085, details={'actual_k': 1, 'was_impossible': False}),
#  Prediction(uid='A27B1U3OWCU14J', iid='B005DKZW2I', r_ui=4.0, est=4.31629248980097, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A2PZXXPGLXXKZU', iid='B0036E8V08', r_ui=4.0, est=3.974312389581907, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A1ZBEIL78MLR9Z', iid='B00DR6DQZA', r_ui=5.0, est=4.561626430985831, details={'actual_k': 10, 'was_impossible': False}),
#  Prediction(uid='A6FIAB28IS79', iid='B001FA1NZK', r_ui=4.0, est=5, details={'actual_k': 4, 'was_impossible': False}),
#  Prediction(uid='A1P0JSFW184ZXJ', iid='B00I3ERXWS', r_ui=5.0, est=4.100167699260344, details={'actual_k': 8, 'was_impossible': False}),
#  Prediction(uid='A2LEIANN1UZTHP', iid='B0044DEDC0', r_ui=2.0, est=4.88303417535028, details={'actual_k': 1, 'was_impossible': False}),
#  Prediction(uid='A1YVO5V1SO18DZ', iid='B009NHWVIA', r_ui=5.0, est=4.791025399352549, details={'actual_k': 38, 'was_impossible': False}),
#  Prediction(uid='A2Y3WWPUKIJ59I', iid='B000NWIOM6', r_ui=4.0, est=3.040672149630002, details={'actual_k': 6, 'was_impossible': False}),
#  Prediction(uid='A1UQBFCERIP7VJ', iid='B005TDWY4I', r_ui=4.0, est=4.391003423232472, details={'actual_k': 6, 'was_impossible': False}),
#  Prediction(uid='ADLVFFE4VBT8', iid='B00HWSXVDG', r_ui=4.0, est=4.331732744358008, details={'actual_k': 4, 'was_impossible': False}),
#  Prediction(uid='ALRCAGJOJ9583', iid='B00BE68UZ6', r_ui=4.0, est=3.7866133550821592, details={'actual_k': 16, 'was_impossible': False}),
#  Prediction(uid='A14JBDSWKPKTZA', iid='B00007KDVK', r_ui=5.0, est=4.181553888457646, details={'actual_k': 3, 'was_impossible': False}),
#  Prediction(uid='A1EVV74UQYVKRY', iid='B001FA1O0O', r_ui=5.0, est=4.335498749173827, details={'actual_k': 7, 'was_impossible': False}),
#  Prediction(uid='A15J9K7O10A3M6', iid='B001G5ZTLS', r_ui=5.0, est=2.655494565325848, details={'actual_k': 2, 'was_impossible': False}),
#  Prediction(uid='AG35JCCQWDRCS', iid='B003M0NT1M', r_ui=4.0, est=5, details={'actual_k': 5, 'was_impossible': False}),
#  Prediction(uid='A1UMSB7LAW0RIR', iid='B009AYVOG6', r_ui=5.0, est=3.6602533593380837, details={'actual_k': 3, 'was_impossible': False}),
#  Prediction(uid='APMYPD97EHUUZ', iid='B002NEG0VO', r_ui=1.0, est=3.5550124228356372, details={'actual_k': 10, 'was_impossible': False}),
#  Prediction(uid='A3V2EZ6MA32FF6', iid='B0090EC5MS', r_ui=5.0, est=4.335829085771688, details={'actual_k': 6, 'was_impossible': False}),
#  Prediction(uid='A2X78O6G89CB30', iid='B000Q8UAWY', r_ui=5.0, est=4.088280637205882, details={'actual_k': 11, 'was_impossible': False}),
#  Prediction(uid='A6TBR6L2D4XKC', iid='B00009XVDB', r_ui=5.0, est=4.124201468658157, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A2V5M5EJPOD2IU', iid='B004G6002M', r_ui=5.0, est=4.714070910476494, details={'actual_k': 17, 'was_impossible': False}),
#  Prediction(uid='A15XI2BEGGFEOW', iid='B004K1EOCA', r_ui=5.0, est=4.353172098743973, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A2LXX47A0KMJVX', iid='B00BERGFV6', r_ui=5.0, est=4.598916322228443, details={'actual_k': 7, 'was_impossible': False}),
#  Prediction(uid='A1Y051MQ2SVPFI', iid='B005O9YMM4', r_ui=5.0, est=3.8687200482243904, details={'actual_k': 1, 'was_impossible': False}),
#  Prediction(uid='AIJQU979J6UFY', iid='B002O3W2OI', r_ui=3.0, est=3.504410949326153, details={'actual_k': 12, 'was_impossible': False}),
#  Prediction(uid='AGOH8N902URMW', iid='B00FR6VL50', r_ui=5.0, est=5, details={'actual_k': 13, 'was_impossible': False}),
#  Prediction(uid='AVPNQUVZWMDSX', iid='B00829TIEK', r_ui=5.0, est=4.493515315364231, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='A1B4MIXYVIKMU2', iid='B00JKM0EQE', r_ui=5.0, est=3.06335882548328, details={'actual_k': 7, 'was_impossible': False}),
#  Prediction(uid='A2QRXQPHDMFCQV', iid='B004GXAL42', r_ui=4.0, est=3.4967388939581907, details={'actual_k': 6, 'was_impossible': False}),
#  Prediction(uid='A
details={'actual_k': 12, 'was_impossible': False}),
#  Prediction(uid='A18HE80910BTZI', iid='B005EJLG28', r_ui=4.0, est=4.053141433099953, details={'actual_k': 8, 'was_impossible': False}),
#  Prediction(uid='ATS2855497V0I', iid='B004M18O60', r_ui=3.0, est=4.006372717168867, details={'actual_k': 4, 'was_impossible': False}),
#  Prediction(uid='AGVWTYW0ULXHT', iid='B00DHPCVQG', r_ui=4.0, est=3.8851173706229, details={'actual_k': 9, 'was_impossible': False}),
#  Prediction(uid='A2PREU4LOFQRB1', iid='B00DR9V1T0', r_ui=4.0, est=4.61204038903645, details={'actual_k': 2, 'was_impossible': False}),
#  Prediction(uid='A32T2H8150OJLU', iid='B00CGWNK2U', r_ui=4.0, est=4.17797255570004, details={'actual_k': 3, 'was_impossible': False}),
#  Prediction(uid='A2XRMQA6PJ5ZJ8', iid='B000TXZIDM', r_ui=5.0, est=4.2818907239950885, details={'actual_k': 12, 'was_impossible': False}),
#  Prediction(uid='A3EXWV8FNSSFL6', iid='B00FWUIYC4', r_ui=5.0, est=4.373839077512531, details={'actual_k': 4, 'was_impossible': False}),
#  Prediction(uid='A2XIOXRRYX0KZY', iid='B002PHLZXC', r_ui=4.0, est=4.618806358030138, details={'actual_k': 6, 'was_impossible': False}),
#  Prediction(uid='A3JUHP1E3WUHEA', iid='B007BZRXK2', r_ui=5.0, est=5, details={'actual_k': 2, 'was_impossible': False}),
#  Prediction(uid='A17V9XL4CWTQ6G', iid='B00DDH4TYA', r_ui=5.0, est=5, details={'actual_k': 5, 'was_impossible': False}),
#  Prediction(uid='A35SNSDRNE9P8Q', iid='B0094NY3R0', r_ui=1.0, est=4.244540420960753, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A2Z9S2RQD542CP', iid='B00746LVOM', r_ui=4.0, est=4.268725448022375, details={'actual_k': 7, 'was_impossible': False}),
#  Prediction(uid='A2KYRPDKVBI2R4', iid='B007XOQ3BQ', r_ui=5.0, est=3.7968877175251015, details={'actual_k': 2, 'was_impossible': False}),
#  Prediction(uid='AONUCJBC85BL', iid='B008TO3X4Y', r_ui=3.0, est=3.411605133006101, details={'actual_k': 2, 'was_impossible': False}),
#  Prediction(uid='A11P105WVK5240', iid='B004S4R5CK', r_ui=5.0, est=4.943504833019107, details={'actual_k': 4, 'was_impossible': False}),
#  Prediction(uid='A1TR1R2QKWRSRA', iid='B002J9HBSE', r_ui=3.0, est=3.900880700700259, details={'actual_k': 3, 'was_impossible': False}),
#  Prediction(uid='AY3XPKRAMKKY7', iid='B00834SJSK', r_ui=5.0, est=4.719328742529934, details={'actual_k': 26, 'was_impossible': False}),
#  Prediction(uid='A1GYEGLX3P2Y7P', iid='B003B4CU3M', r_ui=4.0, est=4.12142723618007, details={'actual_k': 7, 'was_impossible': False}),
#  Prediction(uid='A3OZA8HNJM26DC', iid='B00E0EY7Z6', r_ui=5.0, est=4.221141596076916, details={'actual_k': 10, 'was_impossible': False}),
#  Prediction(uid='A8X8D4BUY5DFU', iid='B006JWMOOI', r_ui=2.0, est=4.8898347379495934, details={'actual_k': 2, 'was_impossible': False}),
#  Prediction(uid='AW5JSQCHC2ZJO', iid='B00JC5Y6YA', r_ui=4.0, est=4.257716406250989, details={'actual_k': 12, 'was_impossible': False}),
#  Prediction(uid='A23GFTVIETX7DS', iid='B005G81E9M', r_ui=4.0, est=3.6169515682710753, details={'actual_k': 9, 'was_impossible': False}),
#  Prediction(uid='AT28RL25Q2OLK', iid='B00IX2VGFA', r_ui=5.0, est=4.833015928893579, details={'actual_k': 13, 'was_impossible': False}),
#  Prediction(uid='A2T689YVOAYGGD', iid='B005M21TBA', r_ui=4.0, est=3.451930119619946, details={'actual_k': 2, 'was_impossible': False}),
#  Prediction(uid='A1WXG10FJ353K0', iid='B007T08XA8', r_ui=4.0, est=3.787832155910301, details={'actual_k': 4, 'was_impossible': False}),
#  Prediction(uid='A379DLIAF0MFM5', iid='B002USUMPI', r_ui=5.0, est=3.378465802882633, details={'actual_k': 3, 'was_impossible': False}),
#  Prediction(uid='AEJAGHLC675A7', iid='B0071BTJPI', r_ui=5.0, est=4.845164225683146, details={'actual_k': 16, 'was_impossible': False}),
#  Prediction(uid='A17UNMURMLX0ZE', iid='B009OZUPUC', r_ui=5.0, est=4.113215607468208, details={'actual_k': 34, 'was_impossible': False}),
#  Prediction(uid='A3NHUQ33CFH3VM', iid='B0079TOEQQ', r_ui=5.0, est=4.243570481587637, details={'actual_k': 32, 'was_impossible': False}),
#  Prediction(uid='A2ME89MSWVG9NF', iid='B003Y74AXO', r_ui=4.0, est=3.179056807810697, details={'actual_k': 19, 'was_impossible': False}),
#  Prediction(uid='A2HRHF83I3NDGT', iid='B009USAJCC', r_ui=5.0, est=5, details={'actual_k': 8, 'was_impossible': False}),
#  Prediction(uid='A3NCIN6TNL0MGA', iid='B0012YHQVE', r_ui=5.0, est=4.392911082925042, details={'actual_k': 0, 'was_impossible': False}),
#  ...]

# %% [markdown]
# we want to calculate percicion@k ,recall@k and f1@k

# %%
from collections import defaultdict
def metrices(model,k=10,threshold=3.5):
    user_est_true=defaultdict(list)
    predictions = model.test(testset)

    for uid,_,r_ui,est,_ in predictions:
        # print(uid,r_ui,est)
        user_est_true[uid].append((est,r_ui))

        
    precisions=dict()
    recalls=dict()
    # user_est_true
    for uid,user_ratings in user_est_true.items():
        # print(uid,user_ratings)
        user_ratings.sort(key=lambda x :x[0], reverse=True)
        # print(uid,user_ratings)
        # print('\n')
        # threshold=3.5
        #number of relevant items
        num_of_relevant=sum((r_ui>=threshold) for (_,r_ui)in user_ratings)
        
        #number of recommended items in top k
        # k=10
        num_of_recommended=(sum((est>=threshold) for (est,_) in user_ratings[:k]))
        
        #number of relevant and recommended

        num_of_both=(sum(  (r_ui>=threshold) and (est>=threshold) for (r_ui,est) in user_ratings[:k]   ))

        precisions[uid]=num_of_both/num_of_recommended if num_of_recommended!=0 else 0

        recalls[uid]=num_of_both/num_of_relevant if num_of_relevant!=0 else 0

    precision=round((sum(prec for prec in precisions.values()) / len(precisions)), 3)
    recall = round((sum(rec for rec in recalls.values()) / len(recalls)), 3)
    f1_score=round(2*precision*recall/(precision+recall),3)
    # accuracy=accuracy.rmse(predictions)
    return precision,recall,f1_score

# %%
print(metrices(base_model))
# Out:
# (0.854, 0.853, 0.853)

# %%
precision,recall,f1=metrices(base_model)

# %%
len(predictions)
# Out:
# 12579

# %%
test_data = pd.DataFrame(testset, columns=['User_ID', 'Product_ID', 'Ratings'])
test_data
# Out:
#               User_ID  Product_ID  Ratings
# 0       AKBVYIIHWI04B  B009SYZ8OC      5.0
# 1      A2MCRCK1V61FWQ  B0009ZBRS0      5.0
# 2      A27B1U3OWCU14J  B005DKZW2I      4.0
# 3      A2PZXXPGLXXKZU  B0036E8V08      4.0
# 4      A1ZBEIL78MLR9Z  B00DR6DQZA      5.0
# ...               ...         ...      ...
# 12574   AIJQU979J6UFY  B00JP12170      4.0
# 12575   ATOKT8QYK967L  B005O7LJAE      2.0
# 12576   AK3GKIV8DEY8B  B000067O7T      3.0
# 12577   ARXU3FESTWMJJ  B001TH7GVE      5.0
# 12578   AO09RWV40IX78  B00DQZOD8Q      5.0
#
# [12579 rows x 3 columns]

# %%
(base_model)

# %%
model = {"model_description": "Knnbaseline: cosine similarity ----user-based",
         "model_details": str(base_model),
         "model_object": base_model}

with open(os.path.join(LOG_PATH, LOG_MODEL_PKL), "wb") as output_file:
    pickle.dump(model, output_file)

# %%
metrices1={'accuracy: ':accuracy,
    'precision: ':precision,
    'recall: ' :recall,
    'f1_score: ':f1
          }
with open (os.path.join(LOG_PATH,LOG_METRICS_PKL),'wb') as output_file:
    pickle.dump(metrices1,output_file)

# %%
data1={'train_data : ':trainset,
      'test_data : ':testset  }
with open (os.path.join(LOG_PATH,LOG_DATA_PKL),'wb') as file:
    pickle.dump(data1,file)

# %%
with mlflow.start_run(experiment_id=exp.experiment_id,
                      run_name=model["model_description"]):
    # Log pickles
    mlflow.log_artifacts(LOG_PATH)

    # Track metrics
    mlflow.log_metric('precision', precision)
    mlflow.log_metric("recall", recall)
    mlflow.log_metric("f1_score", f1)
    mlflow.log_metric("accuracy", accuracy)

# %%
# Predicting rating for a sample user with an interacted product
sample=test_data.sample(1).iloc[0]
base_model.predict(sample["User_ID"], sample["Product_ID"], r_ui=sample["Ratings"], verbose=True)
# Out:
# user: A11I1I9QLMAM1A item: B00E3FHXYO r_ui = 5.00   est = 5.00   {'actual_k': 9, 'was_impossible': False}
# Prediction(uid='A11I1I9QLMAM1A', iid='B00E3FHXYO', r_ui=5.0, est=5, details={'actual_k': 9, 'was_impossible': False})

# %% [markdown]
# Hyperparameter Tuning

# %%
param_grid={'k':[10,20,30,40],
            'min_k':[3,6,9],
            'sim_options':{
                'name' :['msd','cosine','pearson'],
                           'user_based':[True]
                           }
            }
grid=GridSearchCV(KNNBaseline,param_grid=param_grid,measures=['rmse'],cv=5,n_jobs=-1)
grid.fit(data)
print(grid.best_score)
print(grid.best_params)
# Out:
# {'rmse': 0.896583263001412}
# {'rmse': {'k': 30, 'min_k': 9, 'sim_options': {'name': 'pearson', 'user_based': True}}}

# %%
best_params=grid.best_params

# %% [markdown]
# Taraining model on best Parms

# %%
# from surprise import accuracy
sim_options ={'name': 'pearson', 'user_based': True}
model1=KNNBaseline(k=30,min_k=9,sim_options=sim_options)
model1.fit(trainset)
predictions=model1.test(testset)
rmse1=acc.rmse(predictions)
precision,recall,f1=metrices(model1)
# Out:
# Estimating biases using als...
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 0.8887

# %%
acc.rmse(predictions)
# Out:
# RMSE: 0.8887
# 0.8886810203488327

# %%
print(precision)
print(recall)
print(f1)
# Out:
# 0.847
# 0.893
# 0.869

# %%
model1

# %%
model2={'model_description':"KNNBaseline with grid search----user-based ",
        'model_details': str(model1),
        'model_object':model1}
with open (os.path.join(LOG_PATH,LOG_MODEL_PKL),'wb') as output_file:
    pickle.dump(model2,output_file)

# %%
metrices2={'accuracy: ':rmse1,
    'precision: ':precision,
    'recall: ' :recall,
    'f1_score: ':f1
          }
with open (os.path.join(LOG_PATH,LOG_METRICS_PKL),'wb') as output_file:
    pickle.dump(metrices2,output_file)

# %%
with mlflow.start_run(experiment_id=exp.experiment_id,
                      run_name=model2["model_description"]):
    # Log pickles
    mlflow.log_artifacts(LOG_PATH)

    # Track metrics
    mlflow.log_metric('precision', precision)
    mlflow.log_metric("recall", recall)
    mlflow.log_metric("f1_score", f1)
    mlflow.log_metric("accuracy", rmse1)

    mlflow.log_params({
        'k': 30,
        'min_k': 9,
        'sim_options': {'name': 'pearson', 'user_based': True}
    })

# %%
model1.predict('A34BZM6S9L7QI4', '1400501466', verbose=True)
# Out:
# user: A34BZM6S9L7QI4 item: 1400501466 r_ui = None   est = 4.25   {'actual_k': 0, 'was_impossible': False}
# Prediction(uid='A34BZM6S9L7QI4', iid='1400501466', r_ui=None, est=4.246334308439121, details={'actual_k': 0, 'was_impossible': False})

# %%
# Predicting rating for a sample user with an interacted product
sample=test_data.sample(1).iloc[0]
model1.predict(sample["User_ID"], sample["Product_ID"], r_ui=sample["Ratings"], verbose=True)
# Out:
# user: APMYPD97EHUUZ item: B008D4X9UI r_ui = 4.00   est = 4.07   {'actual_k': 1, 'was_impossible': False}
# Prediction(uid='APMYPD97EHUUZ', iid='B008D4X9UI', r_ui=4.0, est=4.0736609034101985, details={'actual_k': 1, 'was_impossible': False})

# %%
model1.predict('ATOKT8QYK967L','B005O7LJAE')
# Out:
# Prediction(uid='ATOKT8QYK967L', iid='B005O7LJAE', r_ui=None, est=4.161209623970819, details={'actual_k': 0, 'was_impossible': False})

# %%
user_item_interactions_matrix=df.pivot(index='User_ID',columns='Product_ID',values='Ratings')
user_item_interactions_matrix
# Out:
# Product_ID      1400501466  1400532655  ...  B00L3YHF6O  B00LGQ6HL8
# User_ID                                 ...
# A100UD67AHFODS         NaN         NaN  ...         NaN         NaN
# A100WO06OQR8BQ         NaN         NaN  ...         NaN         NaN
# A105S56ODHGJEK         NaN         NaN  ...         NaN         NaN
# A105TOJ6LTVMBG         NaN         NaN  ...         NaN         NaN
# A10AFVU66A79Y1         NaN         NaN  ...         NaN         NaN
# ...                    ...         ...  ...         ...         ...
# AZBXKUH4AIW3X          NaN         NaN  ...         NaN         NaN
# AZCE11PSTCH1L          NaN         NaN  ...         NaN         NaN
# AZMY6E8B52L2T          NaN         NaN  ...         NaN         NaN
# AZNUHQSHZHSUE          NaN         NaN  ...         NaN         NaN
# AZOK5STV85FBJ          NaN         NaN  ...         NaN         NaN
#
# [1466 rows x 5523 columns]

# %%
# non_interacted_products=user_item_interactions_matrix.loc['A100UD67AHFODS'][user_item_interactions_matrix.loc['A100UD67AHFODS'].isnull()].index.tolist()
# non_interacted_products
# recommendations=[]
# for i in non_interacted_products:
#     # print(model1.predict('A100UD67AHFODS',i).est)
#     est=model1.predict('A100UD67AHFODS',i).est
#     recommendations.append((i,est))
# recommendations.sort(key=lambda x:x[1],reverse=True)    
# recommendations
# Out:
# [('B0052SCU8U', 4.973286611224055),
#  ('B000N99BBC', 4.919623084419554),
#  ('B001TH7T2U', 4.909452422148865),
#  ('B008EQZ25K', 4.905809993334528),
#  ('B003ES5ZUU', 4.901510778692227),
#  ('B0036Q7MV0', 4.900330856675833),
#  ('B00BQ4F9ZA', 4.897114642949376),
#  ('B0000BZL1P', 4.894640769923062),
#  ('B004ELA0SS', 4.870453988447825),
#  ('B002V8C3W2', 4.8657505834987855),
#  ('B001TH7GUU', 4.865150891842394),
#  ('B000JV9LUK', 4.864968904457252),
#  ('B00316263Y', 4.8617561140632715),
#  ('B005ES0YYA', 4.861361619236413),
#  ('B001UI2FPE', 4.853679587389569),
#  ('B000M2TAN4', 4.852659203266192),
#  ('B001QUA6RA', 4.8511086559331416),
#  ('B0033PRWSW', 4.850227269112632),
#  ('B001TH7GSW', 4.845303473237367),
#  ('B0002LEMWE', 4.8443746047367355),
#  ('B00IVPU6AA', 4.844217743840106),
#  ('B000NP3DJW', 4.843558141600538),
#  ('B00D6XW62I', 4.843342205926016),
#  ('B002JQNXZC', 4.8395606287358),
#  ('B003ES5ZR8', 4.838038620735075),
#  ('B001342KM8', 4.8369896684581875),
#  ('B0019EHU8G', 4.836119774622616),
#  ('B003L1ZYZ6', 4.8354384748620065),
#  ('B0046TJG1U', 4.8322479194097845),
#  ('B00IVFDZBC', 4.831222194189846),
#  ('B00AR95ESC', 4.829792334523991),
#  ('B009NB8WR0', 4.828145171684391),
#  ('B00429N18S', 4.826393905277967),
#  ('B001ENW61I', 4.825342246802636),
#  ('B000F7QRTG', 4.823641385934365),
#  ('B000HPV3RW', 4.821762639255523),
#  ('B00005LEN4', 4.818386627923708),
#  ('B003CFATT2', 4.817799388607175),
#  ('B00E3W15P0', 4.817624566834954),
#  ('B00017LSPI', 4.815406622550528),
#  ('B00009XVCZ', 4.814569781430081),
#  ('B000QUUFRW', 4.8132434131793245),
#  ('B007PJ4P4G', 4.810940647144613),
#  ('B000IJY8DS', 4.810890616237053),
#  ('B006LW0W5Y', 4.808505106035912),
#  ('B006U3O566', 4.807801062552453),
#  ('B009USAJCC', 4.807544703812143),
#  ('B0010Y414Q', 4.804886836834385),
#  ('B00005T3G0', 4.8037595820003665),
#  ('B00BW6KCTU', 4.8036749264355105),
#  ('B004RORMF6', 4.803484082419048),
#  ('B001TH7GUA', 4.803067272482186),
#  ('B000067RT6', 4.802510124281261),
#  ('B000OGX5AM', 4.801409624957396),
#  ('B006W8U2MU', 4.800162908106033),
#  ('B005LDLP8W', 4.8001372486375145),
#  ('B002NO7PWC', 4.8000716030580195),
#  ('B002TLTE6Y', 4.799481724480015),
#  ('B001BTCSI6', 4.798390583444467),
#  ('B00FJRS5BA', 4.797933673110943),
#  ('B00BOHNYU6', 4.796352731268175),
#  ('B001MSU1FS', 4.796088889295989),
#  ('B000AY5Y5W', 4.795642629969825),
#  ('B0000BZL5A', 4.791148439127081),
#  ('B007R5YDYA', 4.790655570529572),
#  ('B001OC6DCW', 4.789149813866572),
#  ('B0010Z28XG', 4.789107561550193),
#  ('B00FR6VL50', 4.788046670482086),
#  ('B000FQ2JLW', 4.786957988873952),
#  ('B00HG1L334', 4.786443296968486),
#  ('B00BOHNYTW', 4.785777385290854),
#  ('B00CKAOJA0', 4.785245207926922),
#  ('B002WE6D44', 4.784405476602261),
#  ('B0076W9Q5A', 4.784087089062481),
#  ('B003DZJQQI', 4.784012050979615),
#  ('B002TMRZOQ', 4.783095754451135),
#  ('B00L3YHF6O', 4.7824146700916454),
#  ('B007BXD66E', 4.782209376236466),
#  ('B003HFCDLY', 4.781891362944206),
#  ('B00007IFED', 4.781076008448139),
#  ('B000VDCT3C', 4.7809753846873955),
#  ('B003ZSHNGS', 4.7792092114630575),
#  ('B001BM5XB2', 4.778876194928375),
#  ('B00D5Q75RC', 4.7784884129875485),
#  ('B001DJ64D4', 4.776048101114137),
#  ('B004GF8TIK', 4.7759628323978705),
#  ('B001XURPQI', 4.7753651804367765),
#  ('B006WAGG14', 4.774766794321737),
#  ('B00007GQLS', 4.7746800357254715),
#  ('B0012Y6HC8', 4.772984463679708),
#  ('B004V4IWHY', 4.771301573648726),
#  ('B0012Y2LLE', 4.770491615367875),
#  ('B0007QKMQY', 4.769415188355002),
#  ('B0036AWR8E', 4.767429789610391),
#  ('B00889ST2G', 4.767294264366278),
#  ('B009NHWVIA', 4.767287587700799),
#  ('B00829TIA4', 4.767126394928006),
#  ('B0035FZ12O', 4.766693878142751),
#  ('B004S4R5CK', 4.765386753695883),
#  ('B005D5M122', 4.765364672882543),
#  ('B003NR57BY', 4.765237420899935),
#  ('B002QAUN2M', 4.764754926523699),
#  ('B0055CAR7Y', 4.76420351386234),
#  ('B003FVJYF8', 4.763947665016212),
#  ('B001F7AHOG', 4.76333250785152),
#  ('B008JJLW4M', 4.762885270661829),
#  ('B00B588HY2', 4.762668030548762),
#  ('B004CLYEFK', 4.761219502314888),
#  ('B004YDUZ22', 4.7603482129023815),
#  ('B0043WJRRS', 4.75915758989306),
#  ('B0099SMFVQ', 4.758400014429676),
#  ('B009APBY0G', 4.758163095550608),
#  ('B006EKIQYM', 4.757791424120978),
#  ('B001M4HXB2', 4.755616903372124),
#  ('B00APCMMDG', 4.754761220488394),
#  ('B0013FRNKG', 4.7541380101184725),
#  ('B00C20KWP4', 4.753689300403177),
#  ('B0017H4G0A', 4.753564581365929),
#  ('B001NTFAOS', 4.75355353657861),
#  ('B000BY52NK', 4.7534927005793906),
#  ('B008EQYRRY', 4.753171603877749),
#  ('B002RCNX8K', 4.752897999112345),
#  ('B003XM1WE0', 4.752806624607328),
#  ('B008LTBITY', 4.752720705951919),
#  ('B002V88HFE', 4.75264501946765),
#  ('B001QATRCA', 4.7523806801053805),
#  ('B00DTZYHX4', 4.751775998719305),
#  ('B004CLYEDC', 4.751575670413125),
#  ('B007FGYZFI', 4.750605738400986),
#  ('B00015GYU4', 4.750456477101335),
#  ('B001V9KG0I', 4.750232198373284),
#  ('B00G4UQ6U8', 4.749811176691314),
#  ('B00HZWJGS8', 4.749717443406301),
#  ('B007WTAJTO', 4.749453504165679),
#  ('B0044YPN0A', 4.748288772138925),
#  ('B0074FGLUM', 4.748054695686532),
#  ('B00006I5J7', 4.747978266193379),
#  ('B001ID829O', 4.747821756920106),
#  ('B002YU83YO', 4.747413108764229),
#  ('B000VDCTCI', 4.747290881415907),
#  ('B00009EHJV', 4.746838744270011),
#  ('B005IMFX2K', 4.746578121324742),
#  ('B000089GN3', 4.745774343571022),
#  ('B004W2JKWG', 4.745747236567247),
#  ('B001OOZ1X2', 4.745700874889944),
#  ('B0000X0VCY', 4.745462612921347),
#  ('B005DSPLCQ', 4.745225826370174),
#  ('B0040JHVC2', 4.745070892365315),
#  ('B00007GQLU', 4.74486562886808),
#  ('B00EO302SO', 4.744058681173853),
#  ('B000VX6XL6', 4.743261806254028),
#  ('B00029U1DK', 4.7431363456464),
#  ('B0058G40O8', 4.742248007942379),
#  ('B003ULNA3K', 4.741815302596954),
#  ('B00GJYJFKM', 4.741218514962806),
#  ('B00COF7DGS', 4.740646986977895),
#  ('B00GBATPFO', 4.740623315061028),
#  ('B002WE4HE2', 4.73943868993006),
#  ('B00BLCVD9I', 4.738548379703869),
#  ('B002WE0QN8', 4.738170919846566),
#  ('B009OBCAW2', 4.738125734332112),
#  ('B000CRFOMK', 4.7376986584599745),
#  ('B000P1O73A', 4.737565508590725),
#  ('B005KAK2FI', 4.73747660133976),
#  ('B000PEF254', 4.737131593560686),
#  ('B001OI2Z4Q', 4.736872684599423),
#  ('B00DT04I9W', 4.7362411343671695),
#  ('B0035FZJHQ', 4.735954693398537),
#  ('B004WB8EYM', 4.735721232395977),
#  ('B000F9YN22', 4.735266699477436),
#  ('B0036V9AGU', 4.7347673604423965),
#  ('B0002XQJFA', 4.734763195267522),
#  ('B007SZ0EOW', 4.734570480670534),
#  ('B003N8GVUY', 4.733813695308598),
#  ('B001PS9E5I', 4.733589737758399),
#  ('B00CD8ADKO', 4.733180493333293),
#  ('B002VPE1X4', 4.733067171751531),
#  ('B002BH3Z8E', 4.732924044269795),
#  ('B003S5SOLG', 4.732879741628097),
#  ('B000RZQZM0', 4.731503654463656),
#  ('B0040723AO', 4.73057109651382),
#  ('B000V5P90K', 4.730239028237392),
#  ('B000VE2RP6', 4.730202977557412),
#  ('B00077AA5Q', 4.729695404533308),
#  ('B000BVC0WO', 4.729604191547756),
#  ('B004MMEHH4', 4.72950586315464),
#  ('B005UA3I72', 4.729191017098902),
#  ('B005GI2VMG', 4.729115083387305),
#  ('B001DBF07I', 4.729072772146269),
#  ('B00CMJZAOI', 4.7290442702801645),
#  ('B00BYRPM9M', 4.728747396991023),
#  ('B0016XIQ1U', 4.727075997969822),
#  ('B001F7AHXM', 4.726988038838719),
#  ('B008OEHPKM', 4.726578118677241),
#  ('B001C271MA', 4.726505118051124),
#  ('B006YLTLUY', 4.726207219075258),
#  ('B002NEGTTW', 4.725215668045225),
#  ('B006TAP096', 4.725012454709216),
#  ('B004EBUXHQ', 4.72495609717),
#  ('B003MTTJOY', 4.724812532375108),
#  ('B001TH7GUK', 4.724006599751252),
#  ('B00081A2KY', 4.72386752518445),
#  ('B006ZT4VA0', 4.72383360270431),
#  ('B00CB2F65O', 4.723607110337402),
#  ('B000068O16', 4.722820864074556),
#  ('B003LSTD38', 4.72246754202969),
#  ('B006DDT6JO', 4.72236862012715),
#  ('B0049V0ZX8', 4.721539212897998),
#  ('B00BANM6HQ', 4.721102896213898),
#  ('B008R6OPJQ', 4.7208659063621345),
#  ('B0011NVMO8', 4.720804779342987),
#  ('B002LTWDSK', 4.720245587265793),
#  ('B004Y1AYAC', 4.719461353502161),
#  ('B00J238GV6', 4.719182500574271),
#  ('B000TKHBDK', 4.719059506872235),
#  ('B00065AO0K', 4.718577639453195),
#  ('B002TLTG9E', 4.718059443716086),
#  ('B00CI3BIWQ', 4.717908612216951),
#  ('B000O8I474', 4.717803261297014),
#  ('B00GTGETFG', 4.717745417267115),
#  ('B00C2P61FO', 4.717729077483658),
#  ('B00BB72WX4', 4.717618512158163),
#  ('B0096W1P6G', 4.717398644863015),
#  ('B0041OSAZ8', 4.717203654843731),
#  ('B006K553LU', 4.71713472764814),
#  ('B00CHH0JF0', 4.717122890999978),
#  ('B00BCA41PW', 4.716770244599878),
#  ('B00D429Y12', 4.716697334239195),
#  ('B00834SJSK', 4.716559248255707),
#  ('B008PQAFR4', 4.716370507231893),
#  ('B000UIA6YM', 4.716364210674065),
#  ('B003VAHYNC', 4.716324547994598),
#  ('B006JH8T3S', 4.716236482631315),
#  ('B00005NIMJ', 4.7153483813234285),
#  ('B0012W7HQK', 4.71509434801872),
#  ('B0002D6QJO', 4.714871853190529),
#  ('B0045KGZOG', 4.714856373748691),
#  ('B000BYCKU8', 4.71437830127327),
#  ('B002PU9SQU', 4.714105387693404),
#  ('B00DR6DQZA', 4.713923173429814),
#  ('B002M3SOCE', 4.713400194412193),
#  ('B00IX2VGFA', 4.713339243685182),
#  ('B0088PUEPK', 4.7128856179266),
#  ('B002AJMHMI', 4.712678084463132),
#  ('B008R7EXCE', 4.712551687815132),
#  ('B0000B006W', 4.712498221229433),
#  ('B0076MBOC8', 4.712447462265115),
#  ('B009YT6PPC', 4.712437070497279),
#  ('B004ING996', 4.712245977301763),
#  ('B006TF37H8', 4.711925378230643),
#  ('B00ISFNSBW', 4.71168748744108),
#  ('B004Q3R9AQ', 4.711403355491827),
#  ('B001EAQTRI', 4.711015684180984),
#  ('B00CGWNKVQ', 4.710966795545036),
#  ('B008ALAHA4', 4.710617007595671),
#  ('B001FVI91U', 4.710532256705096),
#  ('B000Q82PIQ', 4.709680834969965),
#  ('B0035FZ124', 4.70946672162722),
#  ('B00009R6N0', 4.708645562562696),
#  ('B00FPKDPZC', 4.708636624644831),
#  ('B00829THO6', 4.707662561226211),
#  ('B001P05NBA', 4.707640088498799),
#  ('B000ID7QNI', 4.707343305714599),
#  ('B0055QYJIS', 4.707143281662583),
#  ('B000KJQ1DG', 4.7070023546669635),
#  ('B001IEZX3G', 4.706998701747861),
#  ('B00CGYCOR0', 4.7066507674414275),
#  ('B005GGTTZ0', 4.70599440540223),
#  ('B00004XOM3', 4.705953197131322),
#  ('B00G6IJ5NI', 4.70586888647761),
#  ('B0002J2P2A', 4.705482094459401),
#  ('B001T9NUJE', 4.705365543286832),
#  ('B004FA8NOQ', 4.705223218391635),
#  ('B00E3FHXYO', 4.704994842688897),
#  ('B001RNOHDU', 4.7042506859992645),
#  ('B00126V8WU', 4.704173748336734),
#  ('B000CKVOOY', 4.704148069041191),
#  ('B009YQ8BTI', 4.704135349446028),
#  ('B005J31BCO', 4.703866059754829),
#  ('B002IKLJU0', 4.703754034280104),
#  ('B003ZTKFEE', 4.703631593320743),
#  ('B00G4E2IRE', 4.703630441661072),
#  ('B00009MDBQ', 4.7030453742706335),
#  ('B00FZ9SMVU', 4.702659936828906),
#  ('B000I23TTE', 4.702453130383071),
#  ('B007KZQM8W', 4.7014182507164985),
#  ('B000BQ7GW8', 4.700873678462561),
#  ('B00D4MFPLA', 4.7008088849780245),
#  ('B00IRRDHUI', 4.70067590076437),
#  ('B002GP7ZT6', 4.700661892672568),
#  ('B004XC6GJ0', 4.70048641811029),
#  ('B0000511U7', 4.700012037710045),
#  ('B005ELBSWO', 4.699988098619755),
#  ('B002IO2UM2', 4.699913843242805),
#  ('B00AEKEA48', 4.6998527019408325),
#  ('B001S2PPT0', 4.6998165962926794),
#  ('B00B3PDHBU', 4.699708289551721),
#  ('B001PIBE8I', 4.699697670674937),
#  ('B007SZ0E1K', 4.699624188698751),
#  ('B002K9IHGI', 4.699415663114777),
#  ('B005EOWBKE', 4.698889693573362),
#  ('B004286VMW', 4.698838803220777),
#  ('B000JMJWV2', 4.698691874398694),
#  ('B001AW8W7A', 4.69859101493559),
#  ('B000MX48VM', 4.698352222155713),
#  ('B00005AT7Y', 4.698260459671582),
#  ('B008R7EWEI', 4.697995900397742),
#  ('B000AZ57M6', 4.697959352181905),
#  ('B003XM73P2', 4.697873439124793),
#  ('B00BB6LTI4', 4.697294874326042),
#  ('B00212NO6W', 4.697122829796407),
#  ('B00119T6NQ', 4.696826829554277),
#  ('B003XDU2Y0', 4.696559723534253),
#  ('B005LJQMCK', 4.696336502950016),
#  ('B00A2BVBTG', 4.696327274376422),
#  ('B005JN9310', 4.695821580110914),
#  ('B000A0CV9S', 4.695693172105283),
#  ('B0002J2TLC', 4.695655373814835),
#  ('B00ENZRS76', 4.695550518306844),
#  ('B0034CL2ZI', 4.695369744709891),
#  ('B001E1Y5O6', 4.695103700119767),
#  ('B002N2EHVQ', 4.69476103485868),
#  ('B003FVVMS0', 4.694544047073364),
#  ('B00015Y0FK', 4.693624042031107),
#  ('B006FLENJC', 4.693525202920599),
#  ('B000ZMCILW', 4.693388956678848),
#  ('B00DLKE7OQ', 4.692984417196163),
#  ('B000067RVL', 4.692905552820105),
#  ('B0002XQDSS', 4.692661780880928),
#  ('B00008OE6I', 4.692132214430105),
#  ('B00BUJBHGG', 4.692132006168916),
#  ('B0001DBEM4', 4.69210455264101),
#  ('B004IZN3K2', 4.691901220700003),
#  ('B0051QZEHC', 4.691553930022942),
#  ('B00001W0DI', 4.691448834327246),
#  ('B007SZ0EHE', 4.691207284311794),
#  ('B009D79VH4', 4.6911024641729275),
#  ('B000ODN7VM', 4.690836105771184),
#  ('B00006HSYC', 4.690446741832605),
#  ('B001BTG3OQ', 4.69015653050876),
#  ('B005TCMW7S', 4.689936471962474),
#  ('B003UH0Z9Q', 4.689894204908898),
#  ('B004YLCBRG', 4.689572479803855),
#  ('B000Q85WRC', 4.689315238165362),
#  ('B0043T34RK', 4.689082797241555),
#  ('B00ITI058W', 4.688905351718135),
#  ('B00894YP00', 4.688675166769968),
#  ('B005FDXZJU', 4.688596759109723),
#  ('B007M506WS', 4.688478960759429),
#  ('B00009R896', 4.688469255188637),
#  ('B001DL9WDG', 4.688392255884856),
#  ('B00GO4GMAI', 4.6880788014486505),
#  ('B00007E89K', 4.687848559918486),
#  ('B002M3SOC4', 4.687440250855008),
#  ('B001Q3MA80', 4.686974566462241),
#  ('B00EOI2SR2', 4.686924898526074),
#  ('B005FDXF2C', 4.686802746142761),
#  ('B000VOU91U', 4.6866310888834555),
#  ('B003X7TRWE', 4.6862998665806535),
#  ('B000053HC5', 4.686273415928948),
#  ('B002QQ8H8I', 4.685875089306781),
#  ('B000067SGI', 4.685453116193595),
#  ('B000E6NGBU', 4.685260043682009),
#  ('B000M17AVO', 4.685259678183326),
#  ('B002EEP3MK', 4.684765567437235),
#  ('B003MQWN40', 4.684733753811318),
#  ('B00FJWKYYG', 4.684727961104699),
#  ('B001KUL012', 4.684346417222032),
#  ('B00E3RH5W2', 4.684326227570706),
#  ('B00I6CVPVC', 4.6843208151551625),
#  ('B004QQY2JO', 4.684148630835557),
#  ('B000QWEN5K', 4.684134618725417),
#  ('B003GALRIA', 4.684119053358834),
#  ('B00CAAJDP6', 4.683965283525004),
#  ('B006TT91TW', 4.683940212401029),
#  ('B00CPGYNV4', 4.6832676286556545),
#  ('B00BERGFV6', 4.683160823466834),
#  ('B00009R6WO', 4.682599341551824),
#  ('B000B6D39I', 4.682452943394811),
#  ('B005KFONIU', 4.6824266284794005),
#  ('B002TA7VO2', 4.682342382104776),
#  ('B002MZUNXU', 4.682257194247562),
#  ('B000R805L4', 4.682255174879791),
#  ('B005QBK5V2', 4.6822529019314185),
#  ('B0025VKUQQ', 4.682251387043837),
#  ('B00AR95EVE', 4.681819529801598),
#  ('B0012YFXSW', 4.681777779704216),
#  ('B007477COO', 4.681655195061874),
#  ('B00JC5Y6WM', 4.681330122323329),
#  ('B0001CNMFM', 4.681288447007234),
#  ('B0015AARJI', 4.681253507305698),
#  ('B008EC4O76', 4.681217925695767),
#  ('B005DIQ2OC', 4.681201513010314),
#  ('B00B4GGW5Q', 4.681179227710019),
#  ('B009UNZ5WQ', 4.681164862763597),
#  ('B00CSDMWGW', 4.6808083232851185),
#  ('B001UEBN42', 4.680034781078551),
#  ('B000EXS1BS', 4.679885161134385),
#  ('B005J31BCY', 4.679571508315846),
#  ('B000RZ8WHG', 4.6793146683217755),
#  ('B001EQ4BVI', 4.679297599334497),
#  ('B00CKK8GEU', 4.679243444338962),
#  ('B004CLYE8C', 4.678834808701998),
#  ('B000144I30', 4.678495295206845),
#  ('B001I45T9O', 4.678479021761989),
#  ('B00GMTN96U', 4.678364940381585),
#  ('B00B99JU5M', 4.678216012350998),
#  ('B00IVPU59W', 4.6781506889723055),
#  ('B0001XGQTA', 4.677817573358405),
#  ('B000IV413S', 4.677809022698976),
#  ('B006H06TVG', 4.677598114769125),
#  ('B0000BZL0G', 4.677551346340406),
#  ('B0062XB9FE', 4.677279253201242),
#  ('B002W4M0DW', 4.677274375316434),
#  ('B003XIJ3MW', 4.677202528965897),
#  ('B000J1H4VI', 4.6770331255015645),
#  ('B003CJTQJC', 4.677016371510862),
#  ('B00EU9V3YO', 4.676780609704531),
#  ('B001OI2YNS', 4.675971666813355),
#  ('B00FS6O24Q', 4.675963996735125),
#  ('B00008I9K8', 4.675934195496769),
#  ('B00BB6DCUC', 4.675815596315046),
#  ('B00L2442H0', 4.675240497804909),
#  ('B001IEXU68', 4.675171280901945),
#  ('B000EW9Y4M', 4.675142245287082),
#  ('B002SFDJMQ', 4.674979912522167),
#  ('B0031U1ATG', 4.674874586139995),
#  ('B004CADY9I', 4.674719024848129),
#  ('B00434OWDA', 4.6744125017533396),
#  ('B000UMX7FI', 4.67437329241307),
#  ('B001F0RPGG', 4.674164259501813),
#  ('B000053HH5', 4.673743941674742),
#  ('B0027AGK3M', 4.673739041200801),
#  ('B00HZR4DNG', 4.673638760911223),
#  ('B00006B7HB', 4.673611454967081),
#  ('B000M2GYF6', 4.673350475617718),
#  ('B00BK77Z46', 4.673112110913683),
#  ('B000EOSHGQ', 4.672989107033268),
#  ('B00969J3EU', 4.6729340578203455),
#  ('B00EHZYWGM', 4.672904825862836),
#  ('B00005U21H', 4.672629992672617),
#  ('B00829THVO', 4.672306259278043),
#  ('B003WJR69E', 4.672172797168042),
#  ('B00E0HITQ6', 4.672110658838617),
#  ('B00JEVHZHC', 4.672017749160625),
#  ('B002UVNW5W', 4.671866854854517),
#  ('B00003006E', 4.671146718896045),
#  ('B008O2HWTI', 4.670922791797999),
#  ('B002TLTE6O', 4.670763232909179),
#  ('B00080DSEM', 4.670536052508472),
#  ('B00ATM1MGA', 4.670350878466748),
#  ('B0079UAT0A', 4.6701208653039545),
#  ('B004LSNF04', 4.670003041917295),
#  ('B002C744K6', 4.669871504089392),
#  ('B0023Y9EQC', 4.669615290256514),
#  ('B0006I1TRY', 4.669605953833054),
#  ('B005KQ2O26', 4.669549343519303),
#  ('B0099SMFP2', 4.669510480004636),
#  ('B003ATZBWA', 4.66949828685928),
#  ('B0054YQO5C', 4.6694468037492305),
#  ('B000EVSLRO', 4.6693017920593745),
#  ('B001KB6Z2U', 4.668990071361273),
#  ('B00F6E4HXG', 4.668976041844984),
#  ('B0018BQR84', 4.668668542439544),
#  ('B001TUYTZM', 4.668347371160995),
#  ('B0018M256G', 4.668228317053041),
#  ('B004SGJCCO', 4.6681264286734585),
#  ('B00009R94Q', 4.668061882455495),
#  ('B00DSUTVK4', 4.66798527615994),
#  ('B005HXFARS', 4.66784092241138),
#  ('B000WOIFO2', 4.667723914807436),
#  ('B002JCSV5I', 4.667673659933408),
#  ('B005TCC066', 4.667632711385084),
#  ('B003ZG9T62', 4.667448363073793),
#  ('B00CELZD8C', 4.66739659097834),
#  ('B008ALA6DW', 4.66730700697324),
#  ('B000L47AHG', 4.667245724856121),
#  ('B0012IJYZQ', 4.667219014778438),
#  ('B000VWKSHM', 4.666882484062421),
#  ('B000O5N5AI', 4.666870281244128),
#  ('B00284ALF0', 4.666834884518194),
#  ('B007R9M6PO', 4.666823116042915),
#  ('B004HIN7SI', 4.666692199293022),
#  ('B002DUCMQU', 4.66665713581223),
#  ('B00EO96W2I', 4.6664416261285675),
#  ('B0076BNK30', 4.666242456265013),
#  ('B002W2Y8PC', 4.6658907444981095),
#  ('B001W28L2Y', 4.665785922888643),
#  ('B001144JQU', 4.665661951609326),
#  ('B001GCVA0U', 4.665549083330404),
#  ('B004CLYEI2', 4.665420822939957),
#  ('B003SGCO3E', 4.665411386221249),
#  ('B0013AV4M4', 4.665402328360891),
#  ('B004AGX4YO', 4.665365811313651),
#  ('B003LVZO8S', 4.665318922080925),
#  ('B00006HSML', 4.665263941034451),
#  ('B00JWXTOIA', 4.665238994400074),
#  ('B0073FE1F0', 4.664944509919056),
#  ('B00006BBAC', 4.664880299370628),
#  ('B00004SB92', 4.664617216089024),
#  ('B00B50CEH6', 4.664570548880939),
#  ('B00475K64E', 4.664323927778294),
#  ('B000HJPK2C', 4.664262739877107),
#  ('B0002YE6FY', 4.663886737178913),
#  ('B001AHALEC', 4.663818063050413),
#  ('B005LAIFE2', 4.663681798017875),
#  ('B008RDI0TU', 4.663561737626367),
#  ('B00AAIPT76', 4.6634210577388595),
#  ('B00BF9MUAS', 4.663322124446481),
#  ('B002MPPHKY', 4.663304396732124),
#  ('B002QUZM0U', 4.663266765130333),
#  ('B0007Y791C', 4.663040492889737),
#  ('B000UHQVOW', 4.662802254232701),
#  ('B008HK3QII', 4.662530009233089),
#  ('B002MCZJ78', 4.662435512394579),
#  ('B0002L5R78', 4.662369210545695),
#  ('B00006I53W', 4.6623154634623365),
#  ('B00139W0XM', 4.661939439930659),
#  ('B003HIXOOG', 4.661895592691927),
#  ('B000051299', 4.661842586774608),
#  ('B000EPHR0C', 4.661726928937754),
#  ('B005HSDLCO', 4.661628355478358),
#  ('B003ZYF3M8', 4.661554049284457),
#  ('B0001G6U4S', 4.661264733646735),
#  ('B005VFG06W', 4.661147478090951),
#  ('B000VJX7DW', 4.661110663868266),
#  ('B000OG88KY', 4.661084004242305),
#  ('B009NZ6SZE', 4.6608964839679725),
#  ('B000ABB4HC', 4.660838063372065),
#  ('B007FEFQDA', 4.660564132921019),
#  ('B0094S35W4', 4.660256671489464),
#  ('B001PS9UKW', 4.660093902603301),
#  ('B003L62T7W', 4.6599699782933754),
#  ('B00D50UNRM', 4.659758752173618),
#  ('B001O4EPHA', 4.65971498823226),
#  ('B00840353W', 4.659646015730945),
#  ('B006MPUTBC', 4.659565636362038),
#  ('B00DK2JQOQ', 4.65941612299192),
#  ('B002LEVGMO', 4.659238137747132),
#  ('B000NK8EWI', 4.6592119431398755),
#  ('B000I1X3W8', 4.658461069102878),
#  ('B00966IREK', 4.6581853523811505),
#  ('B009X3UW2G', 4.658145415981356),
#  ('B005TDWX2Q', 4.65788853094446),
#  ('B000J47W12', 4.6576907427220124),
#  ('B00746YHV6', 4.657581437879654),
#  ('B0001GMIOE', 4.657430290911479),
#  ('B0053G6GI6', 4.657332974192157),
#  ('B00894YWD0', 4.656424135911425),
#  ('B0056YNA1Q', 4.656220333484941),
#  ('B000JE7GPY', 4.656159644001927),
#  ('B002TLSOG0', 4.656062746033059),
#  ('B00DB9WCR6', 4.655531178863585),
#  ('B007NZGPAY', 4.655292366768886),
#  ('B00DRA4B6Y', 4.655100392633116),
#  ('B006W3ZV5S', 4.6550235915881375),
#  ('B0018MI5F6', 4.654643359065325),
#  ('B004UTQRHW', 4.654561329126399),
#  ('B004R7P28W', 4.654552453758867),
#  ('B00D68Y9B4', 4.654538239640032),
#  ('B0041OYS36', 4.654418373623518),
#  ('B002VKVZ1A', 4.654336231001183),
#  ('B001FA09WI', 4.654098176395416),
#  ('B006ZH0KVG', 4.653903401252654),
#  ('B004U1Y3IU', 4.65377545163075),
#  ('B001QTXL82', 4.653644821447495),
#  ('B00C28L138', 4.65358160347516),
#  ('B001NTFATI', 4.653523508635167),
#  ('B003VANO7C', 4.653358976877568),
#  ('B00DQKQ7U8', 4.653161697762983),
#  ('B004SCSV2U', 4.6531582967475185),
#  ('B000EXRSVM', 4.653064378611512),
#  ('B005J7YA4G', 4.652879029981457),
#  ('B00009USW3', 4.652542223303764),
#  ('B000L9OIQ2', 4.65250978831623),
#  ('B0020ZDI5C', 4.652304265997998),
#  ('B00BQ8RFAI', 4.652288966029198),
#  ('B005HY4U46', 4.65217860966547),
#  ('B00DLKE8C2', 4.651999644316321),
#  ('B00B7E1D7W', 4.651926626453678),
#  ('B0035J7XG2', 4.6517904336091656),
#  ('B000OFWJO6', 4.651520337699922),
#  ('B001RCTA8I', 4.651327047878939),
#  ('B00213FX38', 4.650846074958929),
#  ('B000RY2PLQ', 4.650751767348675),
#  ('B00HA4ORMQ', 4.6507514342767475),
#  ('B00007M1TZ', 4.650725213541115),
#  ('B001G5ZTPY', 4.650643038039843),
#  ('B0011Z2402', 4.650608297714939),
#  ('B00006B9CR', 4.650583324588155),
#  ('B0019CSVMW', 4.650164420665737),
#  ('B00EPY0RI2', 4.650149462123982),
#  ('B00020S7XK', 4.650026436502894),
#  ('B001GIPSAW', 4.649862992524187),
#  ('B00CMRTVFE', 4.649753726839101),
#  ('B004JMZPJQ', 4.649665820609633),
#  ('B002ZIN9DU', 4.6496590579082095),
#  ('B000RHZJN4', 4.64964345882742),
#  ('B009JPBPWO', 4.64959584438471),
#  ('B00HVT27B8', 4.649500029654107),
#  ('B004F9P2KU', 4.649476935746257),
#  ('B00CIZ2238', 4.649224518709452),
#  ('B0016OEV7C', 4.649170182280916),
#  ('B00D1GYNT4', 4.648964432370179),
#  ('B003ZKG10K', 4.648875520300237),
#  ('B003LR7ME6', 4.648789724483193),
#  ('B00DK9N154', 4.6487705994075394),
#  ('B009O7YUF6', 4.648574104314114),
#  ('B002MU1ZRS', 4.64857183025422),
#  ('B0008D76L0', 4.648537732952672),
#  ('B009NHAEXE', 4.6484880608822134),
#  ('B00484IEJS', 4.648288647530128),
#  ('B005EWB396', 4.648096248419321),
#  ('B007VPGL5U', 4.647976992912388),
#  ('B00906HNZU', 4.6479451280309885),
#  ('B0002IWC9C', 4.64789048021263),
#  ('B003I4FHNA', 4.647641199876508),
#  ('B00387EW1K', 4.647528575804161),
#  ('B000BTL0OA', 4.646966781301842),
#  ('B003MVZ60S', 4.64632865563856),
#  ('B00KFAGCUM', 4.646301163118509),
#  ('B00GNN5VBG', 4.6462753091147615),
#  ('B00EU9V3VW', 4.646271672684629),
#  ('B00461E7JE', 4.646173047853235),
#  ('B00GJFGDUQ', 4.646070795574669),
#  ('B000EOMXM0', 4.645928778875641),
#  ('B003EYVP12', 4.645906667465593),
#  ('B0002JY712', 4.645730852476593),
#  ('B002O3KVSC', 4.645568775537875),
#  ('B000OLDG60', 4.645385751889014),
#  ('B003WUBIZQ', 4.6453733874044),
#  ('B004Z0S6RU', 4.645336723075984),
#  ('B00336G7FA', 4.645290007612722),
#  ('B002QGDWLK', 4.645276498792078),
#  ('B000VIHFZ4', 4.645232620211873),
#  ('B0002EQU6C', 4.644910605526836),
#  ('B006OM75I8', 4.644604768058812),
#  ('B0034XRDU0', 4.644598093620766),
#  ('B004SBBD8U', 4.644513069301395),
#  ('B004XW2NEW', 4.644007127106256),
#  ('B00HXIYIE6', 4.643875501212321),
#  ('B0031RG29M', 4.6438262325861945),
#  ('B000GABCY2', 4.64382459125641),
#  ('B0002WPREU', 4.643580505717288),
#  ('B001RHJ60K', 4.643173349322875),
#  ('B001TOD7ME', 4.643068939487945),
#  ('B0047H2KZK', 4.642924608882454),
#  ('B00009R6K7', 4.642751503279864),
#  ('B002S53LJ2', 4.642610936878024),
#  ('B0029N3U8K', 4.642550244344941),
#  ('B005GTNZUM', 4.642544182308568),
#  ('B0019MEIOM', 4.642358999105645),
#  ('B0055N2L22', 4.642283604324135),
#  ('B00006IW1X', 4.6422293946849775),
#  ('B00310PJM0', 4.642124745175454),
#  ('B004GW25WY', 4.6420733325675005),
#  ('B001JYVFLY', 4.6420223778279475),
#  ('B0029EB3OC', 4.642008229558057),
#  ('B009SS0FZK', 4.641927736759409),
#  ('B001A4LVYY', 4.641571461465433),
#  ('B0047ZH0B6', 4.641566752599686),
#  ('B004MF11MU', 4.641548288040674),
#  ('B004TLH6H6', 4.641470674740999),
#  ('B00006B9H8', 4.6412585455163615),
#  ('B00004Z5D1', 4.641239310283024),
#  ('B0090Z3QG6', 4.6411519349979296),
#  ('B000WH6H1M', 4.641120320625912),
#  ('B003RRFWRY', 4.64099040116935),
#  ('B0007G6RZE', 4.6407344048894466),
#  ('B008HK50ZA', 4.640661502511372),
#  ('B001TANZ0W', 4.640574398772366),
#  ('B0079MX4Q4', 4.640407295552229),
#  ('B000136P8W', 4.640370930525464),
#  ('B0081FLFQE', 4.640280278059321),
#  ('B008V9RW58', 4.640252901979743),
#  ('B00E98O7GC', 4.640240555735769),
#  ('B001CCAISE', 4.640223833616905),
#  ('B00EOE4G4E', 4.640186317808254),
#  ('B0058UUR6E', 4.640071313347273),
#  ('B000VJRUKS', 4.6400154686064585),
#  ('B000ANCPNM', 4.63993858850843),
#  ('B003UI62AG', 4.63980377761597),
#  ('B001HSOFI2', 4.639403660720082),
#  ('B0007WK8KS', 4.639229300902853),
#  ('B003WKOENO', 4.639125622647171),
#  ('B004IK2EAW', 4.6389980571954235),
#  ('B001QUA6R0', 4.6389848830169775),
#  ('B00267S7XW', 4.63897392675392),
#  ('B003U7SR0U', 4.638942471185499),
#  ('B0038KN114', 4.638905395239977),
#  ('B0058FAYPI', 4.638784154521332),
#  ('B0081ER9KG', 4.638565798687845),
#  ('B00HFRWWAM', 4.638542236207534),
#  ('B002PAX9QU', 4.638394187210582),
#  ('B005CWHZP4', 4.638194092842744),
#  ('B00305N48C', 4.638150821106213),
#  ('B003ES5ZQE', 4.638111525028789),
#  ('B004S5CCP4', 4.638014288927939),
#  ('B00CALM17C', 4.637746791300078),
#  ('B0001HWL9A', 4.637684449961161),
#  ('B009BZX340', 4.6375975491985715),
#  ('B0013FNZ1M', 4.63756637704739),
#  ('B00AANQLRI', 4.637497133876917),
#  ('B0041D81WQ', 4.637465604534968),
#  ('B000EMWBV0', 4.637454057117625),
#  ('B00FAYL1YU', 4.637296319692941),
#  ('B0010Z294O', 4.63726333035129),
#  ('B005QZ8BCI', 4.637167698169615),
#  ('B003WGJYCY', 4.637113151651483),
#  ('B000075UZ7', 4.637001260564899),
#  ('B00DVS98XS', 4.636953692555789),
#  ('B004X355Y6', 4.636938928038171),
#  ('B0011ZCDKS', 4.636922039076234),
#  ('B00AZW4MYI', 4.6368349328180996),
#  ('B000N7VPRW', 4.636832159973079),
#  ('B00DDH4TYA', 4.636742698723042),
#  ('B00FZ9SM4M', 4.63671436268725),
#  ('B0031RG2JC', 4.63669079173916),
#  ('B00B4QESVQ', 4.636588832494051),
#  ('B004HHICKC', 4.636550555464736),
#  ('B00JDAIMQ2', 4.636430716300787),
#  ('B0015EA3NO', 4.636392887790657),
#  ('B000068O34', 4.636217710240478),
#  ('B00DW374W4', 4.636190492792506),
#  ('B00CEZBKTO', 4.636167223657649),
#  ('B0037LQY7M', 4.636118430572502),
#  ('B00HFW1E6K', 4.6359954075531205),
#  ('B003SX0P1A', 4.635487845191276),
#  ('B005NGKR54', 4.635393610859676),
#  ('B00622AG6S', 4.635276042959385),
#  ('B007JCNOHS', 4.635165123657526),
#  ('B004SKBJYE', 4.635161391071427),
#  ('B001FWBUUG', 4.63509478473934),
#  ('B0079M711S', 4.634936381625707),
#  ('B00APP6694', 4.63483057657518),
#  ('B00004RC2D', 4.634628925289509),
#  ('B000FFISV8', 4.634453672605822),
#  ('B000ENUCR4', 4.634355140059884),
#  ('B005C95NCY', 4.634190833072447),
#  ('B0067WUSGQ', 4.634138918168547),
#  ('B00BLGUKEI', 4.633980217643491),
#  ('B000KO0GY6', 4.633737972506995),
#  ('B004FHO5Y6', 4.633716588173207),
#  ('B001ENOZY4', 4.633655962439938),
#  ('B004HKJTT2', 4.63345467609936),
#  ('B005DQG5SC', 4.633427383677327),
#  ('B00E1CZRHY', 4.63337340595923),
#  ('B00007FGU7', 4.633153561539987),
#  ('B0000AI0N1', 4.633075341119035),
#  ('B00G0OYHCW', 4.633052391417094),
#  ('B000VZS2EU', 4.6323091042150555),
#  ('B0013LQD7Y', 4.632098844643198),
#  ('B001EM9JXC', 4.632095771168872),
#  ('B003ZUIHY8', 4.632030578290563),
#  ('B001ASU1QO', 4.631881605486296),
#  ('B00006I53X', 4.631559341277766),
#  ('B001FA1O1S', 4.631514658625129),
#  ('B00D7P6176', 4.631349511167134),
#  ('B000F2BLTM', 4.63127255045149),
#  ('B00F1CRTLK', 4.6312699142047915),
#  ('B00DMS0GTC', 4.631188701390711),
#  ('B000S5Q9CA', 4.630785906962864),
#  ('B003LPTAYI', 4.630624853341328),
#  ('B001N9X4CS', 4.630616255571652),
#  ('B004G6002M', 4.630450401105162),
#  ('B00009R6JT', 4.630380775314069),
#  ('B004LTEUDO', 4.630173140287156),
#  ('B00CD1FB26', 4.629933629146085),
#  ('B0090BSSZO', 4.629923562812914),
#  ('B006B7R9PU', 4.6298624920432125),
#  ('B004N3BH0C', 4.629612551546683),
#  ('B00A0JUNWQ', 4.629518253474405),
#  ('B001MSU1HG', 4.629487342327199),
#  ('B000JLK5PK', 4.6294380622187745),
#  ('B0012GK3MQ', 4.6292053628923195),
#  ('B002PX9BX2', 4.629038950037655),
#  ('B00IVPU6GO', 4.628877667593737),
#  ('B00224ZDFY', 4.628714911773192),
#  ('B001NLV4TQ', 4.628658867457116),
#  ('B001FO4QHI', 4.628454390663642),
#  ('B005IHAI8O', 4.628361677842476),
#  ('B0011U65F2', 4.628201393117153),
#  ('B001FN14RE', 4.628045654577243),
#  ('B0041Q38NU', 4.627773358976328),
#  ('B0012X43P2', 4.627762725238038),
#  ('B00009R6WT', 4.627122121895113),
#  ('B004ZNA3UA', 4.627117343207044),
#  ('B0013G8PTS', 4.627088407410419),
#  ('B00B7JLZQQ', 4.627064401010598),
#  ('B000144I2Q', 4.6270546869872735),
#  ('B00740MR78', 4.62693958056592),
#  ('B001QFZMBU', 4.626923126159466),
#  ('B001S0PWWC', 4.626597302481169),
#  ('B002OOWC3I', 4.626188724164321),
#  ('B00GK22DF2', 4.626184254095565),
#  ('B006W3ZWXE', 4.625962845143994),
#  ('B004L9M4C8', 4.625909661682357),
#  ('B00000K4KH', 4.625817843499373),
#  ('B005JW6WQU', 4.625756260130548),
#  ('B00006B81E', 4.6257534162157725),
#  ('B001SER47O', 4.625472812570407),
#  ('B003N12TSY', 4.625439966348036),
#  ('B00JOS04PK', 4.625172186001695),
#  ('B0009HTB0Y', 4.624962707314421),
#  ('B0093H4WT6', 4.624937724298559),
#  ('B0009I4VE4', 4.624877152226477),
#  ('B007IV7KRU', 4.624826356863563),
#  ('B004C3AW40', 4.624817631966349),
#  ('B000V01RLK', 4.624754951298417),
#  ('B008TCUXLW', 4.624659109290862),
#  ('B000HGIWN4', 4.624374058167048),
#  ('B004BLIQDC', 4.624371354991617),
#  ('B000VUIXOO', 4.624354659804132),
#  ('B00EDCF0MY', 4.6242116141417435),
#  ('B001TZWNF0', 4.624027461505148),
#  ('B00G4V0QSK', 4.6240108840752985),
#  ('B00009R6WY', 4.624006126473899),
#  ('B00HMREOLK', 4.623971822756012),
#  ('B0021AFZOI', 4.623798106197689),
#  ('B003ZM7YTA', 4.623694916992277),
#  ('B00ENZRP38', 4.623530181321225),
#  ('B004QJ9JLW', 4.623471541487321),
#  ('B004JZI78O', 4.623425239099702),
#  ('B009SGB3KI', 4.623069247314413),
#  ('B000FKQ8LA', 4.622851040144706),
#  ('B005JACJ50', 4.622811465010491),
#  ('B008RM235I', 4.622809931773428),
#  ('B009EADB2Q', 4.622715240668694),
#  ('B0082N9BZM', 4.622681160649579),
#  ('B0002Y5WZM', 4.622650277721131),
#  ('B0047ZFHBG', 4.622446907040435),
#  ('B008MB71IS', 4.6223360428191995),
#  ('B000QZ0036', 4.622287882031136),
#  ('B0000AZK0D', 4.622172562723213),
#  ('B00F19Q7AC', 4.621893036162732),
#  ('B001DJ64C0', 4.621858724923289),
#  ('B009NHAF5G', 4.621772046370523),
#  ('B000096B01', 4.621681367065847),
#  ('B005755U0I', 4.621573824759182),
#  ('B000MP831G', 4.6215113712760765),
#  ('B00000DM9W', 4.621328404781477),
#  ('B008DW95NA', 4.621316803606129),
#  ('B004Q3R9B0', 4.621305348056474),
#  ('B000097O5F', 4.621152729656653),
#  ('B007RMAS1K', 4.6210330317750605),
#  ('B004OR14GO', 4.620932621804925),
#  ('B000O8WE66', 4.6208885373750475),
#  ('B009SYZ8OC', 4.62085443430621),
#  ('B00IJU0K2Q', 4.620843545751747),
#  ('B000NOEDGK', 4.620747396228223),
#  ('B001EPUQAE', 4.6206621404479025),
#  ('B007VL8Y2C', 4.62026085525873),
#  ('B007PTCFFW', 4.620132500953737),
#  ('B00E7LSCNK', 4.619926148317248),
#  ('B0010YWPZ8', 4.619874145331739),
#  ('B0002D03ZW', 4.619697534607773),
#  ('B00AXTQQDS', 4.619503442209918),
#  ('B00B5HE3UU', 4.619494000960429),
#  ('B00HZ9GNGY', 4.619419432021838),
#  ('B000LRMR26', 4.619346020961494),
#  ('B001KBZ3SC', 4.6193026470374665),
#  ('B005LFT3GG', 4.61911250943006),
#  ('B000U3DY4Q', 4.619083167525682),
#  ('B002JP92K8', 4.6188390203028415),
#  ('B005UBNKWO', 4.618682586011082),
#  ('B001FWU96M', 4.618507360034339),
#  ('B003ZTWYXY', 4.618279627788292),
#  ('B001MSVPM6', 4.618243514138141),
#  ('B00IVPU5BK', 4.618191075178037),
#  ('B004YKXGIK', 4.618137464449299),
#  ('B00829THEG', 4.6181010975492205),
#  ('B000H4CLXS', 4.618076327110015),
#  ('B00EOI2SYK', 4.617919122407745),
#  ('B000KZ70JE', 4.617893954392534),
#  ('B003BKW2K2', 4.617819843739852),
#  ('B000JLP5UK', 4.617773022282018),
#  ('B006QB1RPY', 4.617742262332343),
#  ('B004EBX5GW', 4.6177334805677415),
#  ('B000204SWE', 4.617562693492263),
#  ('B003YNQ6MG', 4.617518001987247),
#  ('B005F778JO', 4.617468911780761),
#  ('B000092TT0', 4.617421710970639),
#  ('B00005LENO', 4.617375468484035),
#  ('B005AWYB2Q', 4.617322269015828),
#  ('B007PJ4Q4A', 4.617291213912853),
#  ('B000KUQ8FG', 4.617219455306188),
#  ('B004I5FL1G', 4.617056550647012),
#  ('B00EDIU5IW', 4.616736679176294),
#  ('B00H7PBWK8', 4.616699642002486),
#  ('B001NS828K', 4.616570501084313),
#  ('B0045J2LVS', 4.616549486191307),
#  ('B003M0NT1M', 4.616400944833503),
#  ('B004BQTTE2', 4.6163999407281455),
#  ('B003TOE4PQ', 4.616380491031292),
#  ('B007KEZMX4', 4.616250432152509),
#  ('B002K23V1Q', 4.616237334443774),
#  ('B006JINHYS', 4.615877681987793),
#  ('B00EVIBN8U', 4.615617569360096),
#  ('B00BEHRQB4', 4.615562989257995),
#  ('B0093HKFYW', 4.61543202701194),
#  ('B0016D1I0G', 4.615278143854908),
#  ('B002YTDE5I', 4.615213804283863),
#  ('B00H7F9IVI', 4.615170195056839),
#  ('B001S0RUFY', 4.614950290858426),
#  ('B000JJSQ30', 4.61487996210979),
#  ('B00752R9PK', 4.61485661538456),
#  ('B008AL9VXI', 4.614835276501405),
#  ('B001TH7GT6', 4.614823801208976),
#  ('B0064X5Q5Q', 4.614424535425831),
#  ('B000BN94F8', 4.614336422477341),
#  ('B002JCSV8A', 4.614148370140054),
#  ('B00IF4OATU', 4.614105859797915),
#  ('B00IUF7VKE', 4.614053706680928),
#  ('B00609B3J2', 4.613963556441272),
#  ('B00AJHDZSI', 4.613815525071814),
#  ('B003N7NMO8', 4.613750734960859),
#  ('B003ZSP0WW', 4.613414291129276),
#  ('B00IMZKDOS', 4.613340770804029),
#  ('B0000BVYTV', 4.613330342994108),
#  ('B00EKAPZ8S', 4.613215853643357),
#  ('B009X01C64', 4.612994169847632),
#  ('B0065DUJ0C', 4.612917308748507),
#  ('B00A9NE84C', 4.612757317467088),
#  ('B000TS7I6C', 4.612659972558477),
#  ('B0009JZSKO', 4.6124737178287685),
#  ('B0094S360U', 4.612470713100549),
#  ('B002IKLJVE', 4.612415803297223),
#  ('B00HLAGR0E', 4.612393733602916),
#  ('B007Z419BI', 4.612356626664493),
#  ('B00D02AHEO', 4.612326288130643),
#  ('B000E5CYW8', 4.612273544741564),
#  ('B0078ZZ5Q4', 4.612174128131948),
#  ('B000093UDQ', 4.612125344620285),
#  ('B000BSJFJS', 4.612007592716995),
#  ('B001E25JOA', 4.611889713512609),
#  ('B00D6XSRL2', 4.611768678307227),
#  ('B00JF0D7RE', 4.611546514027793),
#  ('B003CJTR8M', 4.611507772648422),
#  ('B0060B7NCG', 4.611447179704615),
#  ('B0035JJOLE', 4.6114335506538335),
#  ('B0046TDJJK', 4.611408442270192),
#  ('B001X017G2', 4.611355623259137),
#  ('B004CLYJ0K', 4.611323390514142),
#  ('B0025EWXEU', 4.6112729112559565),
#  ('B00008Y0VN', 4.611258794148508),
#  ('B00346I5LI', 4.611217497970062),
#  ('B003OBUJIK', 4.611143386308382),
#  ('B0048IATQ0', 4.610942856871354),
#  ('B000XZCIX4', 4.610648283011506),
#  ('B00871F9E6', 4.6105897193954775),
#  ('B00480OTHI', 4.610487751769695),
#  ('B004Q0PT3I', 4.610378301815609),
#  ('B00DB3SH2G', 4.6103744648489435),
#  ('B001S2RCWI', 4.610333629115048),
#  ('B007BYLLNI', 4.610265154154447),
#  ('B00390JT1O', 4.610257624653539),
#  ('B00EKJQLSC', 4.610247059676557),
#  ('B00CIY0KOM', 4.610238525137446),
#  ('B000I1YIDQ', 4.610233855271655),
#  ('B0002YE686', 4.61003595245401),
#  ('B0062MXHCS', 4.609968697550744),
#  ('B00DKBU5W4', 4.609866508404784),
#  ('B003ZBZ64Q', 4.609851875703038),
#  ('B003A7CDY6', 4.609732418273749),
#  ('B000V1XICU', 4.609618047803108),
#  ('B001NJ3H0C', 4.6095252697820985),
#  ('B002SIMPXM', 4.6093175237919874),
#  ('B006U1YVZ8', 4.609316221494403),
#  ('B005IHAIC0', 4.6093095281613),
#  ('B00E87E1OM', 4.609270499849408),
#  ('B001F8SCRE', 4.609251903534633),
#  ('B00CXACPN0', 4.609175743885403),
#  ('B000F34FVM', 4.60912132642354),
#  ('B00KH8PUDW', 4.609043917432678),
#  ('B0090IA4FO', 4.608751058979798),
#  ('B00DBA9YD0', 4.608689266928401),
#  ('B004LB4MZS', 4.608667863915237),
#  ('B006ZBWV0K', 4.608625610824889),
#  ('B004CLYEH8', 4.6085465537581305),
#  ('B000GHD73Y', 4.60851989795076),
#  ('B00009UT9B', 4.608454785809688),
#  ('B002SQKL7Q', 4.608310590486808),
#  ('B002RWJHBM', 4.6082861333971366),
#  ('B00HR7FWUC', 4.608220486600532),
#  ('B00DVEJA7G', 4.608091697241744),
#  ('B003A7C9WM', 4.607988118807808),
#  ('B00J5174TU', 4.607837369989324),
#  ('B003O1UYHG', 4.607728879839204),
#  ('B003FWEQDM', 4.6075320178896195),
#  ('B000G6M91G', 4.607519729388019),
#  ('B002VPE1Q6', 4.607058878400892),
#  ('B0002TPFTA', 4.607011145986536),
#  ('B00F0S0DK4', 4.606976480111755),
#  ('B0028AD7BE', 4.606835094514395),
#  ('B007P71IM0', 4.606695387536069),
#  ('B001T9NX9Q', 4.606581658203548),
#  ('B000AYJDD6', 4.606571003370352),
#  ('B003PJ6QVU', 4.606510640074131),
#  ('B00505EZZ6', 4.606469819969654),
#  ('B00B6ZCNGM', 4.606463817617979),
#  ...]

# %%
def get_recommendations(data,user_id,top_n,model):
    user_item_interactions_matrix=df.pivot(index='User_ID',columns='Product_ID',values='Ratings')

    non_interacted_products=user_item_interactions_matrix.loc[user_id][user_item_interactions_matrix.loc[user_id].isnull()].index.tolist()
    recommendations=[]
    for i in non_interacted_products:
        est=model.predict('user_id',i).est
        recommendations.append((i,est))
    recommendations.sort(key=lambda x:x[1],reverse=True)    
    return recommendations[:top_n+1]

# %%
get_recommendations(df, 'A3LDPF5FMB782Z', 20, model1)
# Out:
# [('B0052SCU8U', 4.836800187278955),
#  ('B000N99BBC', 4.783136660474454),
#  ('B001TH7T2U', 4.772965998203765),
#  ('B008EQZ25K', 4.769323569389428),
#  ('B003ES5ZUU', 4.765024354747127),
#  ('B0036Q7MV0', 4.763844432730733),
#  ('B00BQ4F9ZA', 4.760628219004276),
#  ('B0000BZL1P', 4.758154345977962),
#  ('B004ELA0SS', 4.733967564502725),
#  ('B002V8C3W2', 4.7292641595536855),
#  ('B001TH7GUU', 4.7286644678972936),
#  ('B000JV9LUK', 4.728482480512152),
#  ('B00316263Y', 4.725269690118171),
#  ('B005ES0YYA', 4.724875195291313),
#  ('B001UI2FPE', 4.717193163444469),
#  ('B000M2TAN4', 4.716172779321092),
#  ('B001QUA6RA', 4.7146222319880415),
#  ('B0033PRWSW', 4.713740845167532),
#  ('B001TH7GSW', 4.708817049292267),
#  ('B0002LEMWE', 4.7078881807916355),
#  ('B00IVPU6AA', 4.707731319895006)]
