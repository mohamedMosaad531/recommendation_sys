# %%
import pandas as pd
import mlflow
from mlflow import MlflowClient

# %%
MLFLOW_TRACKING_URI = '../models/mlruns/'
MLFLOW_EXPERIMENT_NAME = "Amazon_products_recommendation_system"

# %%
mlflow.set_tracking_uri(MLFLOW_TRACKING_URI)
client=MlflowClient()

# %%
experiment=client.get_experiment_by_name(MLFLOW_EXPERIMENT_NAME)
experiment
# Out:
# <Experiment: artifact_location=('file:///c:/Users/Mohamed '
#  'Mosaad/Downloads/recommendation_system/notebooks/../models/mlruns/597160538808927604'), creation_time=1729802209573, experiment_id='597160538808927604', last_update_time=1729802209573, lifecycle_stage='active', name='Amazon_products_recommendation_system', tags={}>

# %%
runs=mlflow.search_runs([experiment.experiment_id])
runs
# Out:
#                              run_id       experiment_id    status  \
# 0  6fb98e2cb5f64178aedc2bc4a605a482  597160538808927604  FINISHED
# 1  afae8fbb017e4552be94a446aa5220db  597160538808927604  FINISHED
# 2  9decf65fa68840b2a21b53cec6a91dba  597160538808927604  FINISHED
# 3  129e0b5c60754aab872c2647fd4209fe  597160538808927604  FINISHED
# 4  8edae64485fe483dad549a23b90e461c  597160538808927604  FINISHED
# 5  7029ba919e114b2bac69707034b64251  597160538808927604    FAILED
# 6  c7c8bcc3a51b48bda56be211d5c173ad  597160538808927604    FAILED
# 7  39399e91212441af99d289a7b05053fb  597160538808927604  FINISHED
# 8  9aa7b0ccd77f4a83b3c10f7e5ba80c85  597160538808927604    FAILED
#
#                                         artifact_uri  \
# 0  file:///c:/Users/Mohamed Mosaad/Downloads/reco...
# 1  file:///c:/Users/Mohamed Mosaad/Downloads/reco...
# 2  file:///c:/Users/Mohamed Mosaad/Downloads/reco...
# 3  file:///c:/Users/Mohamed Mosaad/Downloads/reco...
# 4  file:///c:/Users/Mohamed Mosaad/Downloads/reco...
# 5  file:///c:/Users/Mohamed Mosaad/Downloads/reco...
# 6  file:///c:/Users/Mohamed Mosaad/Downloads/reco...
# 7  file:///c:/Users/Mohamed Mosaad/Downloads/reco...
# 8  file:///c:/Users/Mohamed Mosaad/Downloads/reco...
#
#                         start_time                         end_time  \
# 0 2024-10-26 21:22:42.252000+00:00 2024-10-26 21:22:42.325000+00:00
# 1 2024-10-26 21:14:52.118000+00:00 2024-10-26 21:14:52.181000+00:00
# 2 2024-10-26 16:16:49.634000+00:00 2024-10-26 16:16:49.903000+00:00
# 3 2024-10-26 15:55:39.571000+00:00 2024-10-26 15:55:39.890000+00:00
# 4 2024-10-25 20:37:12.724000+00:00 2024-10-25 20:37:12.836000+00:00
# 5 2024-10-25 20:36:40.956000+00:00 2024-10-25 20:36:41.029000+00:00
# 6 2024-10-25 20:36:25.065000+00:00 2024-10-25 20:36:25.202000+00:00
# 7 2024-10-25 18:11:05.539000+00:00 2024-10-25 18:11:05.621000+00:00
# 8 2024-10-25 18:09:40.479000+00:00 2024-10-25 18:09:40.605000+00:00
#
#    metrics.recall  metrics.accuracy  metrics.f1_score  metrics.precision  \
# 0           0.819          0.890000             0.859              0.903
# 1           0.824          0.901000             0.863              0.906
# 2           0.788          1.033728             0.847              0.916
# 3           0.788          1.033728             0.847              0.916
# 4           0.893          0.888681             0.869              0.847
# 5           0.893          0.888681             0.869              0.847
# 6           0.893               NaN             0.869              0.847
# 7           0.853          0.941522             0.853              0.854
# 8             NaN               NaN               NaN                NaN
#
#   params.lr_all params.reg_all params.n_epochs params.min_k  \
# 0          0.01            0.2              20         None
# 1          None           None            None         None
# 2          None           None            None            6
# 3          None           None            None         None
# 4          None           None            None            9
# 5          None           None            None         None
# 6          None           None            None         None
# 7          None           None            None         None
# 8          None           None            None         None
#
#                         params.sim_options params.k tags.mlflow.user  \
# 0                                     None     None   Mohamed Mosaad
# 1                                     None     None   Mohamed Mosaad
# 2     {'name': 'msd', 'user_based': False}       20   Mohamed Mosaad
# 3                                     None     None   Mohamed Mosaad
# 4  {'name': 'pearson', 'user_based': True}       30   Mohamed Mosaad
# 5                                     None     None   Mohamed Mosaad
# 6                                     None     None   Mohamed Mosaad
# 7                                     None     None   Mohamed Mosaad
# 8                                     None     None   Mohamed Mosaad
#
#                                  tags.mlflow.runName tags.mlflow.source.type  \
# 0                svd:with gridsearch ----model_based                   LOCAL
# 1                            SVD--------model_based                    LOCAL
# 2       KNNBasic:with gridsearch ----item-item based                   LOCAL
# 3  KNNBZsiv=c: cosine similarity ----item-item based                   LOCAL
# 4        KNNBaseline with grid search----user-based                    LOCAL
# 5        KNNBaseline with grid search----user-based                    LOCAL
# 6        KNNBaseline with grid search----user-based                    LOCAL
# 7      Knnbaseline: cosine similarity ----user-based                   LOCAL
# 8      Knnbaseline: cosine similarity ----user-based                   LOCAL
#
#                              tags.mlflow.source.name
# 0  c:\Users\Mohamed Mosaad\anaconda3\Lib\site-pac...
# 1  c:\Users\Mohamed Mosaad\anaconda3\Lib\site-pac...
# 2  c:\Users\Mohamed Mosaad\anaconda3\Lib\site-pac...
# 3  c:\Users\Mohamed Mosaad\anaconda3\Lib\site-pac...
# 4  c:\Users\Mohamed Mosaad\anaconda3\Lib\site-pac...
# 5  c:\Users\Mohamed Mosaad\anaconda3\Lib\site-pac...
# 6  c:\Users\Mohamed Mosaad\anaconda3\Lib\site-pac...
# 7  c:\Users\Mohamed Mosaad\anaconda3\Lib\site-pac...
# 8  c:\Users\Mohamed Mosaad\anaconda3\Lib\site-pac...
